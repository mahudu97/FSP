# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Regression-Methods" data-toc-modified-id="Regression-Methods-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Regression Methods</a></span><ul class="toc-item"><li><span><a href="#Processing-stock-price-data-in-Python" data-toc-modified-id="Processing-stock-price-data-in-Python-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Processing stock price data in Python</a></span><ul class="toc-item"><li><span><a href="#Natural-log-plot" data-toc-modified-id="Natural-log-plot-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Natural log plot</a></span></li><li><span><a href="#252-Days-sliding-window" data-toc-modified-id="252-Days-sliding-window-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>252 Days sliding window</a></span></li><li><span><a href="#Simple-and-Log-return-time-series" data-toc-modified-id="Simple-and-Log-return-time-series-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Simple and Log return time-series</a></span></li><li><span><a href="#Suitability-of-log-returns-and-the-Jarque-Bera-test" data-toc-modified-id="Suitability-of-log-returns-and-the-Jarque-Bera-test-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Suitability of log returns and the Jarque-Bera test</a></span></li><li><span><a href="#Simple-and-logarithmic-returns" data-toc-modified-id="Simple-and-logarithmic-returns-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>Simple and logarithmic returns</a></span></li><li><span><a href="#Preference-of-simple-returns-over-log-returns" data-toc-modified-id="Preference-of-simple-returns-over-log-returns-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>Preference of simple returns over log returns</a></span></li></ul></li><li><span><a href="#ARMA-vs.-ARIMA-Models-for-Financial-Applications" data-toc-modified-id="ARMA-vs.-ARIMA-Models-for-Financial-Applications-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>ARMA vs. ARIMA Models for Financial Applications</a></span><ul class="toc-item"><li><span><a href="#Log-closing-price-of-the-S&amp;P-500-from-2015-to-2019" data-toc-modified-id="Log-closing-price-of-the-S&amp;P-500-from-2015-to-2019-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Log closing price of the S&amp;P 500 from 2015 to 2019</a></span></li><li><span><a href="#Fit-an-ARMA(1,0)" data-toc-modified-id="Fit-an-ARMA(1,0)-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Fit an ARMA(1,0)</a></span></li><li><span><a href="#Fit-an-ARIMA(1,1,0)" data-toc-modified-id="Fit-an-ARIMA(1,1,0)-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Fit an ARIMA(1,1,0)</a></span></li><li><span><a href="#Log-prices-for-the-ARIMA-analysis" data-toc-modified-id="Log-prices-for-the-ARIMA-analysis-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Log prices for the ARIMA analysis</a></span></li></ul></li><li><span><a href="#Vector-Autoregressive-(VAR)-Models" data-toc-modified-id="Vector-Autoregressive-(VAR)-Models-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Vector Autoregressive (VAR) Models</a></span><ul class="toc-item"><li><span><a href="#VAR-Matrix-form" data-toc-modified-id="VAR-Matrix-form-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>VAR Matrix form</a></span></li><li><span><a href="#Optimal-set-of-coefficients-for-the-matrix-B" data-toc-modified-id="Optimal-set-of-coefficients-for-the-matrix-B-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Optimal set of coefficients for the matrix B</a></span></li><li><span><a href="#Stability-of-a-VAR(1)-process" data-toc-modified-id="Stability-of-a-VAR(1)-process-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Stability of a VAR(1) process</a></span></li><li><span><a href="#Evaluation-of-selected-stocks-from-S&amp;P-500" data-toc-modified-id="Evaluation-of-selected-stocks-from-S&amp;P-500-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Evaluation of selected stocks from S&amp;P 500</a></span></li><li><span><a href="#Evaluation-of-sectors-in-S&amp;P-500" data-toc-modified-id="Evaluation-of-sectors-in-S&amp;P-500-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Evaluation of sectors in S&amp;P 500</a></span></li></ul></li></ul></li><li><span><a href="#Bond-pricing" data-toc-modified-id="Bond-pricing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Bond pricing</a></span><ul class="toc-item"><li><span><a href="#Examples-of-bond-pricing" data-toc-modified-id="Examples-of-bond-pricing-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Examples of bond pricing</a></span></li><li><span><a href="#Forward-rates" data-toc-modified-id="Forward-rates-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Forward rates</a></span></li><li><span><a href="#Duration-of-a-coupon-bearing-bond" data-toc-modified-id="Duration-of-a-coupon-bearing-bond-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Duration of a coupon-bearing bond</a></span></li><li><span><a href="#Capital-Asset-Pricing-Model-(CAPM)-and-Arbitrage-Pricing-Theory-(APT)" data-toc-modified-id="Capital-Asset-Pricing-Model-(CAPM)-and-Arbitrage-Pricing-Theory-(APT)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Capital Asset Pricing Model (CAPM) and Arbitrage Pricing Theory (APT)</a></span><ul class="toc-item"><li><span><a href="#Average-of-company-returns" data-toc-modified-id="Average-of-company-returns-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Average of company returns</a></span></li><li><span><a href="#Rolling-beta" data-toc-modified-id="Rolling-beta-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Rolling beta</a></span></li><li><span><a href="#Capital-weighted-market-return" data-toc-modified-id="Capital-weighted-market-return-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Capital weighted market return</a></span></li><li><span><a href="#Capital-weighted-rolling-beta" data-toc-modified-id="Capital-weighted-rolling-beta-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Capital weighted rolling beta</a></span></li><li><span><a href="#APT-for-a-two-factor-model" data-toc-modified-id="APT-for-a-two-factor-model-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>APT for a two factor model</a></span></li></ul></li></ul></li><li><span><a href="#Portfolio-Optimization" data-toc-modified-id="Portfolio-Optimization-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Portfolio Optimization</a></span><ul class="toc-item"><li><span><a href="#Adaptive-minimum-variance-portfolio-optimization" data-toc-modified-id="Adaptive-minimum-variance-portfolio-optimization-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Adaptive minimum-variance portfolio optimization</a></span><ul class="toc-item"><li><span><a href="#Derivation-of-the-minimum-variance-portfolio" data-toc-modified-id="Derivation-of-the-minimum-variance-portfolio-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Derivation of the minimum-variance portfolio</a></span></li><li><span><a href="#Performance-of-a-portfolio-with-two-strategies" data-toc-modified-id="Performance-of-a-portfolio-with-two-strategies-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Performance of a portfolio with two strategies</a></span></li><li><span><a href="#Adaptive-time-varying-minimum-variance-portfolio" data-toc-modified-id="Adaptive-time-varying-minimum-variance-portfolio-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Adaptive time-varying minimum variance portfolio</a></span></li></ul></li></ul></li><li><span><a href="#Robust-Statistics-and-Non-Linear-Methods" data-toc-modified-id="Robust-Statistics-and-Non-Linear-Methods-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Robust Statistics and Non Linear Methods</a></span><ul class="toc-item"><li><span><a href="#Data-Import-and-Exploratory-Data-Analysis" data-toc-modified-id="Data-Import-and-Exploratory-Data-Analysis-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Data Import and Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Importing-data-and-evaluating-the-statistics" data-toc-modified-id="Importing-data-and-evaluating-the-statistics-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Importing data and evaluating the statistics</a></span></li><li><span><a href="#PDF-of-the-adjusted-close-and-the-returns" data-toc-modified-id="PDF-of-the-adjusted-close-and-the-returns-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>PDF of the adjusted close and the returns</a></span></li><li><span><a href="#Rolling-mean,-median-and-standard-deviations" data-toc-modified-id="Rolling-mean,-median-and-standard-deviations-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Rolling mean, median and standard deviations</a></span></li><li><span><a href="#Introducing-outliers" data-toc-modified-id="Introducing-outliers-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Introducing outliers</a></span></li><li><span><a href="#Box-plot-of-the-stocks" data-toc-modified-id="Box-plot-of-the-stocks-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Box plot of the stocks</a></span></li></ul></li><li><span><a href="#Robust-Estimators" data-toc-modified-id="Robust-Estimators-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Robust Estimators</a></span><ul class="toc-item"><li><span><a href="#Estimator-functions" data-toc-modified-id="Estimator-functions-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Estimator functions</a></span></li><li><span><a href="#Efficiency" data-toc-modified-id="Efficiency-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Efficiency</a></span></li><li><span><a href="#Breakdown-point-of-the-estimators" data-toc-modified-id="Breakdown-point-of-the-estimators-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Breakdown point of the estimators</a></span></li></ul></li><li><span><a href="#Robust-and-OLS-Regression" data-toc-modified-id="Robust-and-OLS-Regression-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Robust and OLS Regression</a></span><ul class="toc-item"><li><span><a href="#OLS-daily-returns-regression-of-stocks-against-DJI" data-toc-modified-id="OLS-daily-returns-regression-of-stocks-against-DJI-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>OLS daily returns regression of stocks against DJI</a></span></li><li><span><a href="#Huber-daily-returns-regression-of-stocks-against-DJI" data-toc-modified-id="Huber-daily-returns-regression-of-stocks-against-DJI-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Huber daily returns regression of stocks against DJI</a></span></li><li><span><a href="#Performance-of-the-regression-with-outliers" data-toc-modified-id="Performance-of-the-regression-with-outliers-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Performance of the regression with outliers</a></span></li></ul></li><li><span><a href="#Robust-Trading-Strategies" data-toc-modified-id="Robust-Trading-Strategies-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Robust Trading Strategies</a></span><ul class="toc-item"><li><span><a href="#Moving-average-crossover" data-toc-modified-id="Moving-average-crossover-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Moving average crossover</a></span></li><li><span><a href="#Moving-median-crossover" data-toc-modified-id="Moving-median-crossover-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Moving median crossover</a></span></li></ul></li></ul></li><li><span><a href="#Graphs-in-Finance" data-toc-modified-id="Graphs-in-Finance-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Graphs in Finance</a></span><ul class="toc-item"><li><span><a href="#Selection-of-stocks" data-toc-modified-id="Selection-of-stocks-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Selection of stocks</a></span></li><li><span><a href="#Plot-a-correlation-matrix-network" data-toc-modified-id="Plot-a-correlation-matrix-network-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Plot a correlation matrix network</a></span></li><li><span><a href="#Topology-of-the-graph" data-toc-modified-id="Topology-of-the-graph-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Topology of the graph</a></span></li><li><span><a href="#Spectral-distance" data-toc-modified-id="Spectral-distance-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Spectral distance</a></span></li><li><span><a href="#Correlation-network-for-raw-prices" data-toc-modified-id="Correlation-network-for-raw-prices-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Correlation network for raw prices</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Regression Methods
#
# ## Processing stock price data in Python
#
# Financial signal processing studies the fluctuation of the value of assets based on historical data of either the same asset or other elements. For this coursework different techniques will be discussed and evaluated. The programming language used is Python 3, which comes with many statistical libraries that will be used for this experiment.
#
# First, some modules will be loaded such as numpy, pandas and scipy. Then the data will be loaded from the file priceData.csv. Since it is labeled, the appropriate column is extracted. Due to the fact that there are indexes whose values are NaN, they are removed alongside their corresponding dates.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy import stats
import random
import pdb
from statsmodels.tsa.arima_model import ARIMA, ARMA
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.api import VAR
from statsmodels import robust
import copy
import datetime as dt
import warnings
from sklearn.linear_model import LinearRegression, HuberRegressor
from sklearn.decomposition import PCA
import pandas_datareader as web
import time
import networkx as nx
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Read data from priceData.csv
px = pd.read_csv('priceData.csv')
spx = px['SPX Index']
dates = px['date']

# Remove NaN from the dataset and adjust the dates
spx_indices = np.where(px['SPX Index'].isna() == False)[0]
spx = spx[spx_indices]
dates = dates[spx_indices]

date_axis = [dt.datetime.strptime(d,'%d/%m/%Y').date() for d in dates]

# %% [markdown]
# ### Natural log plot

# %% [markdown]
# The following code uses matplotlib to display the log transformed SPX index from the year 1930 to 2017.

# %%
# Perform the natural logarithm transform of the data
logpx = np.log(spx)

plt.figure(dpi=100, figsize=(5,3))
plt.plot(date_axis,logpx)
plt.title('Natural logarithm of SPX Index data')
plt.xlabel('date')
plt.ylabel('log Points')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# ### 252 Days sliding window
#
# The evolution of the first and second order statistics (mean and variance) is computed and displayed. They are calculated using a sliding window of 252 days with a 1 day increment. Due to the exponential behaviour of the stock market, the price volatility increases with the increase in value. However, in terms of percentage it does not. A stock loosing $100 in value was more relevant in 1930 than in 2017 but a loss of 10\% of the value is equaly important. The simple price index captures the exponential behaviour of the trend but fails to provide a realistic view of what the variance is when analyzing the whole century.
#
# On the other hand, the log transform gives a linear representation of the growth of the SPX index and it makes the analysis much easier. The log transform of the SPX Index variance turns it into a stationary times-series where it can be seen when the economic downturns occured.

# %%
# Sliding mean
plt.figure(dpi=100, figsize=(8,6))
plt.subplot(221)
plt.title('252 day rolling mean of SPX Index data')
plt.xlabel('date')
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.plot(date_axis,spx.rolling(252).mean())

# Sliding standard deviation
plt.subplot(222)
plt.plot(date_axis,spx.rolling(252).var())
plt.title('252 day rolling variance of SPX')
plt.xlabel('date')
plt.tight_layout()
plt.grid()
plt.xticks(rotation=45)

# Log Sliding mean
# plt.figure(dpi=100)
plt.subplot(223)
plt.plot(date_axis,logpx.rolling(252).mean())
plt.title('252 day rolling mean of Log SPX')
plt.xlabel('date')
plt.tight_layout()
plt.xticks(rotation=45)
plt.grid()

# Log Sliding standard deviation
plt.subplot(224)
plt.plot(date_axis,logpx.rolling(252).var())
plt.title('252 day rolling variance of Log SPX')
plt.xlabel('date')
plt.tight_layout()
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# ### Simple and Log return time-series
#
# The return, sliding mean and variance of the return and the log return are displayed. As it can be observed in the figures, the advantage of employing the return instead of the real value of the index lies on the stationarity of the time series. The time series obtained from exercise 1.1.1 are nonstationary which is not desirable for the task of trend extraction. The log return and simple return variance are very similar due to the linear behaviour of the log function for very small values.

# %%
# Simple return
plt.figure(dpi=100, figsize=(12,8))
plt.subplot(321)
simpret = spx.pct_change()
plt.title('Return of SPX Index data')
plt.xlabel('date')
plt.plot(date_axis,simpret)
plt.tight_layout()
plt.xticks(rotation=45)
plt.grid()

# Sliding mean simple return
plt.subplot(322)
simpret_roll_mean = spx.pct_change().rolling(252).mean()
plt.title('252 day sliding mean of the return of SPX Index data')
plt.xlabel('date')
plt.plot(date_axis,simpret_roll_mean)
plt.tight_layout()
plt.xticks(rotation=45)
plt.grid()

# Sliding variance simple return
plt.subplot(323)
simpret_roll_var = spx.pct_change().rolling(252).var()
plt.title('252 day sliding variance of the return of SPX Index data')
plt.xlabel('date')
plt.plot(date_axis,simpret_roll_var)
plt.tight_layout()
plt.xticks(rotation=45)
plt.grid()

# Log return
plt.subplot(324)
logret = logpx.diff()
plt.plot(date_axis,logret)
plt.title('Log return of SPX Index data')
plt.xlabel('date')
plt.tight_layout()
plt.xticks(rotation=45)
plt.grid()

# Sliding mean Log return
plt.subplot(325)
logret_roll_mean = logpx.diff().rolling(252).mean()
plt.plot(date_axis,logret_roll_mean)
plt.title('252 day sliding mean of log return of SPX Index data')
plt.xlabel('date')
plt.tight_layout()
plt.xticks(rotation=45)
plt.grid()

# Sliding var Log return
plt.subplot(326)
logret_roll_var = logpx.diff().rolling(252).var()
plt.plot(date_axis,logret_roll_var)
plt.title('252 day sliding variance of log return of SPX Index data')
plt.xlabel('date')
plt.tight_layout()
plt.grid()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Suitability of log returns and the Jarque-Bera test
#
# Log returns are of great importance in signal processing and are many times used over simple returns. Some of the reasons for this are its properties of time additivity (see section 1.1.5), mathematical tractability (exponents are easy to manipulate) and numerical stability (addition of small numbers is less prone to error than multiplication). Furthermore, log returns are less susceptible to outliers since any data-point that significantly deviates from the mean is compressed.
#
# The Jarque-Bera test evaluates how well a gaussian model fits the time series being evaluated. It tests whether the kurtosis and skweness of the model is similar to that of a normal distribution. For its implementation, the scipy library is used. The p-value returned by the algorithm is 0. This means that the null hypothesis is rejected and the time-series does not follow a normal distribution.

# %%
# Return the Jarque-Bera test p-value for a time-series x
p_value = stats.jarque_bera(spx)[1]
p_value
# Out:
# 0.0

# %% [markdown]
# ### Simple and logarithmic returns
#
# The listing below illustrates the function that computes the simple and log returns. One advantage of log returns is that they are time-additive. If an asset whose value is 1 increases to 2 and then goes back down to 1 then when using the simple return function, the purchaser of this asset does not have a return of 0 by the end of the day. However, if log returns are used, the final return is equal to zero.

# %%
price = [1, 2, 1]

# Simple return
R = np.zeros(3)
R[0] = 0            # There is no return on the first day
for t in range(1,3):
    R[t] = (price[t]-price[t-1])/price[t-1]
print('Simple return:', R)
print('Purchaser ends up with:' + str(sum(R)) + ' $')

# Log return
r = np.zeros(3)
r[0] = 0            # There is no return on the first day
for t in range(1,3):
    r[t] = np.log(price[t]/price[t-1])
print('Logarithmic return:', r)
print('Purchaser ends up with:' + str(sum(r)) + ' $')
# Out:
# Simple return: [ 0.   1.  -0.5]
# Purchaser ends up with:0.5 $
# Logarithmic return: [ 0.          0.69314718 -0.69314718]
# Purchaser ends up with:0.0 $

# %% [markdown]
# ### Preference of simple returns over log returns
#
# Although log returns are easier to manipulate mathematically. There are some reasons because of which simple returns can be preferred over log returns. When the time frame of analysis is large, the assumption of log-normality of the distribution does not hold because the skewness of financial data is negative and that of the model is positive.

# %% [markdown]
# ## ARMA vs. ARIMA Models for Financial Applications
#
# An autoregresive moving average ARMA(p,q) process is a model used to predict stationary data. It consists of an AR part that autoregresses its own past values and an MA part that models the behaviour of the error based on previous error terms. The first intends to explain the momentum and reversion effects from trading markets and it's of order p-AR-lags. The later attempts to model the shock events present in financial data and it's of order q-MA-lags. This process requires the time-series to be stationary.
#
# On the other hand, the autoregressive integrated moving average ARMA(p,d,q) is the same as ARMA but with the addition of a differencing component that makes the time-series stationary.

# %% [markdown]
# ### Log closing price of the S&P 500 from 2015 to 2019
#
# The log transform of the S&P 500 time-series is displayed above. It can be observed that it is a nonstationary time-series. Because of this, the task of modeling the time-series is better suited for an ARIMA process than for an ARMA process.

# %%
snp = pd.read_csv('snp_500_2015_2019.csv')
dates = snp['Date']
date_axis = [dt.datetime.strptime(d,'%Y-%m-%d').date() for d in dates]
snp_close = snp['Close'].to_frame().apply(np.log)
plt.figure(dpi=100, figsize=(5,3))
plt.plot(date_axis, snp_close)
plt.xticks(rotation=45)
plt.title('Log closing price of S&P 500 from 2015 to 2019')
plt.xlabel('date')
plt.ylabel('log points')
plt.grid()
plt.show()

# %% [markdown]
# ### Fit an ARMA(1,0)
#
# An ARMA(1,0) is employed to predict on one day basis the S&P 500 during the period from 2015 to 2019. The resulting MSE can be seen below.

# %%
snp_arma = copy.deepcopy(snp_close)
snp_arma.columns = ['True']
model = ARIMA(snp_arma, order=(1,0,0))
result = model.fit()
snp_arma['Res'] = result.resid
snp_arma['Prediction'] = snp_arma['True'] - snp_arma['Res']
plt.figure(dpi=100, figsize=(5,3))
plt.plot(date_axis, snp_close, 'blue')
print('Prediction MSE: ', np.mean((np.array(snp_arma['Prediction']) - np.array(snp_close)))**2)
plt.plot(date_axis, snp_arma['Prediction'], 'red',linewidth=0.8)
plt.xticks(rotation=45)
plt.title('ARMA prediction of log S&P 500 from 2015 to 2019')
plt.xlabel('date')
plt.ylabel('log points')
plt.legend(['True', 'ARMA(1,0) prediction'])
plt.grid()
plt.show()
# Out:
# Prediction MSE:  1.1982109409265327e-08

# %% [markdown]
# The coefficients of the AR process are shown below. It can be obersved that there is a clear correlation between the present value and the inmediate past.

# %%
print(result.params)
print('The second value of the true time series is: ', snp_arma['True'][1])
print('The second value of the predicted time series is: ', snp_arma['Prediction'][1])
# Out:
# const         7.739997
# ar.L1.True    0.997359
# dtype: float64
# The second value of the true time series is:  7.611139856145701
# The second value of the predicted time series is:  7.629878627852597

# %% [markdown]
# When calculating the coefficients of a higher order AR process, namely, AR(5) it becomes clear that a sample two time samples away from the present had barely no effect because the AR coefficients with index above one are nearly zero. Any AR model of higher order than 1 would be overfitting.
#
# The use of an AR(1) for time-series forecasting is of very little practicality. The model takes the immediate past value and adds white noise to it. There is no useful information in the previous time values that can be used to forecast the future. Under a completely efficient market scenario, this model would be the best since any future values are just a random walk from the previous state.

# %%
snp_arma = copy.deepcopy(snp_close)
snp_arma.columns = ['True']
params = ARIMA(snp_arma, order=(5,0,0)).fit().params

plt.figure(dpi=100, figsize=(5,3))
plt.bar([1,2,3,4,5],np.array([params['ar.L' + str(i) +'.True'] for i in range(1,6)]))
plt.title('Coefficients of AR(5)')
plt.xlabel('coefficient')
plt.grid()
plt.show()

# %% [markdown]
# ### Fit an ARIMA(1,1,0)
#
# An ARIMA(1,1,0) is used to forecast one time step ahead for the same time-series. Since there is only one time-step ahead forecast, the use of an ARIMA will give the same results as the ARMA used in the previous exercise and no model is better than the other.

# %%
snp_arma = copy.deepcopy(snp_close)
snp_arma.columns = ['True']
snp_arma['Res'] = ARIMA(snp_arma, order=(1,1,0)).fit().resid
snp_arma['Prediction'] = snp_arma['True'] - snp_arma['Res']

plt.figure(dpi=100, figsize=(5,3))
plt.plot(date_axis, snp_close, 'blue')
print('Prediction MSE: ', np.mean((np.array(snp_arma['Prediction']) - np.array(snp_close)))**2)
plt.plot(date_axis, snp_arma['Prediction'], 'red', linewidth=0.8)
plt.xticks(rotation=45)
plt.title('ARIMA prediction of log S&P 500 from 2015 to 2019')
plt.xlabel('date')
plt.ylabel('log points')
plt.legend(['True', 'ARIMA(1,1.0) prediction'])
plt.grid()
plt.show()
# Out:
# Prediction MSE:  nan

# %% [markdown]
# ### Log prices for the ARIMA analysis
#
# One of the advantages of using log prices for the time-series is that the variance is made stationary and the system more stable. This helps in the task of forecasting the time-series. Moreover, for the short time period from 2014 to 2019, the time-series has a log-normality distribution which makes taking the log of the prices more suitable.

# %% [markdown]
# ## Vector Autoregressive (VAR) Models
#
# Vector autoregression (VAR) is a probabilistic process that models the linear interdependencies of different time-series. It's a generalization of the AR model for more than one variable.

# %% [markdown]
# ### VAR Matrix form
#
# The vector autoregressive model can be represented in matrix form as
#
# \begin{equation}
# Y = BZ + U \\
# \end{equation}
# where
# \begin{equation}
#     Y =
#     \begin{pmatrix}
#         y_{1,T-1} & y_{1,T-2} & \cdots & y_{1,0} \\
#         y_{2,T-1} & y_{2,T-2} & \cdots & y_{2,0} \\
#         \vdots        &       \vdots  & \ddots &       \vdots \\
#         y_{K,T-1} & y_{K,T-2} & \cdots & y_{K,0} \\
#     \end{pmatrix}
# \end{equation}
#
#
# \begin{equation}
#     B =
#     \begin{pmatrix}
#         c_{1}      &      a_{1,1}^{1} & a_{1,2}^{1} & \cdots & a_{1,K}^{1} & a_{1,1}^{2} \cdots & a_{1,K}^{P} \\
#         c_{2}      &      a_{2,1}^{1} & a_{2,2}^{1} & \cdots & a_{2,K}^{1} & a_{2,1}^{2} \cdots & a_{2,K}^{P} \\
#         \vdots      &      \vdots        &       \vdots  & \ddots &       \vdots  &  \vdots \quad  \ddots & \vdots \\
#         c_{K}      &      a_{K,1}^{1} & a_{K,2}^{1} & \cdots & a_{K,K}^{1} & a_{K,1}^{2} \cdots & a_{K,K}^{P} \\
#     \end{pmatrix}
# \end{equation}
#
# \begin{equation}
#     Z =
#     \begin{pmatrix}
#             1             &        1      & \cdots &     1     \\
#         y_{1,t-1}^{1} & y_{1,t-2}^{1} & \cdots & y_{1,t-p}^{1} \\
#         y_{2,t-1}^{1} & y_{2,t-2}^{1} & \cdots & y_{2,t-p}^{1} \\
#         \vdots        &       \vdots  & \ddots &       \vdots \\
#         y_{K,t-1}^{1} & y_{K,t-2}^{1} & \cdots & y_{K,t-p}^{1} \\
#         y_{1,t-1}^{2} & y_{1,t-2}^{2} & \cdots & y_{1,t-p}^{2} \\
#         \vdots        &       \vdots  & \ddots &       \vdots \\
#         y_{K,t-1}^{p} & y_{K,t-2}^{p} & \cdots & y_{K,t-p}^{p} \\
#     \end{pmatrix}
# \end{equation}
#
# \begin{equation}
#     U =
#     \begin{pmatrix}
#         e_{1,T-1} & e_{1,T-2} & \cdots & e_{1,0} \\
#         e_{2,T-1} & e_{2,T-2} & \cdots & e_{2,0} \\
#         \vdots    &   \vdots  & \ddots &   \vdots \\
#         e_{K,T-1} & e_{K,T-2} & \cdots & e_{K,0} \\
#     \end{pmatrix}
# \end{equation}

# %% [markdown]
# ### Optimal set of coefficients for the matrix B
#
# In order to minimize the error of the function above, an LSE estimator is used for the model. The cost function is given by:
#
# \begin{equation}
# J(B) = (Y-BZ)^{T}(Y-BZ)
# \end{equation}
#
# when expanded, it turns into
#
# \begin{equation}
# J(B) = YY^{T} - 2Y^{T}BZ + Z^{T}B^{T}BZ
# \end{equation}
#
# The aim is to minimize the cost function:
#
# \begin{equation}
# \frac{J(B)}{dB} = 0
# \end{equation}
#
# This results in:
#
# \begin{equation}
# -2YZ^{T} + B_{opt}(ZZ^{T}+ZZ^{T}) = 0 \\
# \end{equation}
# \begin{equation}
# -2YZ^{T} + 2B_{opt}ZZ^{T} = 0
# \end{equation}
#
# Finally, the optimal parameters are given by:
#
# \begin{equation}
# B_{opt} = YZ^{T}(ZZ^{T})^{-1}
# \end{equation}

# %% [markdown]
# ### Stability of a VAR(1) process
#
# A VAR(1) process is given by the following equation
#
# \begin{equation}
# y_{t} = Ay_{t-1} + e_{t}
# \end{equation}
#
# For the system to be stable the eigenvalues of the matrix \textbf{A} must be smaller than one in absolute value. This is proven by taking the Z-transform:
#
# \begin{equation}
# Y(z) = AY(z)z^{-1} + E(z)\\
# \end{equation}
# \begin{equation}
# Y(z)(I-Az^{-1}) = E(z)\\
# \end{equation}
# \begin{equation}
# H(z) = (I-Az^{-1})^{-1}\\
# \end{equation}
# \begin{equation}
# A = QDQ^{-1} \Rightarrow H(z) = (I - QDQ^{-1}z^{-1})^{-1}\\
# \end{equation}
# \begin{equation}
# \text{where } A \text{ has been diagonalized.}\\
# \end{equation}
#
# \begin{equation}
# \text{For the system to be stable, there must be no poles. This happens when }\\
# \end{equation}
# \begin{equation}
# |\lambda| < 1
# \end{equation}

# %% [markdown]
# ### Evaluation of selected stocks from S&P 500
#
# 5 stocks from the S&P 500 are selected and evaluated. In order to detrend the time-series and turn them stationary, an MA(66) is applied.

# %%
df = pd.read_csv(r'snp_allstocks_2015_2019.csv')
dates = df['Date']
date_axis = [dt.datetime.strptime(d,'%Y-%m-%d').date() for d in dates]
df = df.set_index('Date')
info = pd.read_csv(r'snp_info.csv')
info.drop(columns=info.columns[0] ,inplace = True)
tickers = ['CAG', 'MAR' ,'LIN' ,'HCP' ,'MAT' ]
stocks = df[tickers]
stocks_ma = stocks.rolling(window=66).mean()
stocks_detrended = stocks.sub(stocks_ma).dropna()
model = VAR(stocks_detrended)
results = model.fit(1)
A = results.params[1:].values
eigA, _ = np.linalg.eig(A)

plt.figure(dpi=100, figsize=(12,4))
plt.subplot(121)
plt.plot(date_axis,stocks)
plt.title('SNP selected stocks from 2015 to 2019')
plt.xlabel('date')
plt.ylabel('price ($)')
plt.xticks(rotation=45)
# plt.legend(tickers)
plt.tight_layout()
plt.grid()

plt.subplot(122)
plt.plot([date_axis[i] for i in np.linspace(0,len(date_axis)-1,87).astype(int)],stocks_detrended)
plt.xticks(rotation=45)
plt.xlabel('date')
plt.ylabel('price ($)')

plt.title('SNP detrended stocks from 2015 to 2019')
# plt.legend(tickers,bbox_to_anchor=(0, 1), loc='upper left', ncol=1)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# The eigenvalues of the regression matrix A are displayed below. It can be seen that all the eigenvalues of A are positive. However, because eigenvalue 3 is larger than 1, the system is unstable. When selecting a portfolio, it is of interest to find stocks that are very highly correlated (positively or negatively) or very independent. This does not seem to be the case for this portfolio, and, therefore, it is not a good investment option.

# %%
plt.figure(dpi=100, figsize=(5,3))
plt.bar([1,2,3,4,5],eigA)
plt.title('Eigenvalues of the regression matrix A')
plt.xlabel('Eigenvalue')
plt.grid()
plt.show()

# %% [markdown]
# ### Evaluation of sectors in S&P 500
#
# In this exercise the stocks are grouped by sectors and then analyzed. An MA(66) is applied to detrend the time-series and the result is then displayed. Investing in a sector rather than in individual diversified stocks conveys a greater risk. If an external event causes an bad effect on that industry, all the stocks will plummet and conversely. However, it will minimize the within-sector risk since they will all follow a similar trend if they are correlated. Many times, companies within the same sector are competitors. If one company grows it could cause another company to shrink. A minimization of risk can be accomplished by having a portfolio of investments in different sectors.
#
# From a modeling point of view, it is more stable to analyze stocks by sector than by individual values. This way it gives an overall performance of the industry that is less sensitive to individual fluctuations. Moreover, grouping the stocks by sector can provide meaningful information about how much a stock can be valued if a certain market level is reached and can help in the estimation of the future value of a company.

# %%
sector = info['GICS Sector'].unique()[random.randint(0,len(info['GICS Sector'].unique())-1)]
tickers = info.loc[info['GICS Sector'] == sector]['Symbol'].tolist()
stocks = df[tickers]
stocks_ma = stocks.rolling(window=66).mean()
stocks_detrended = stocks.sub(stocks_ma).dropna()
model = VAR(stocks_detrended)
results = model.fit(1)
A = results.params[1:].values
eigA, _ = np.linalg.eig(A)

plt.figure(dpi=100, figsize=(12,4))
plt.subplot(121)
plt.plot(date_axis,stocks)
plt.title('Stocks of the sector of ' + str(sector))
plt.ylabel('price ($)')
plt.xlabel('date')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid()

plt.subplot(122)
plt.plot(np.array(stocks_detrended))
plt.title('Detrended stocks of the sector of ' + str(sector))
plt.ylabel('price ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# # Bond pricing

# %% [markdown]
# ## Examples of bond pricing
#
# An investor will be given £1100 in one year for an investment of £1000 now. It is of interest to calculate the percentage return with an annual, semi-annual, monthly and continuous period of compounding. These are given by the equations below:
#
# \begin{equation}\label{eq:annual_compounding}
# r_{1} = C_{i} \times (1+r_{f})\quad \text{Annual compounding}
# \end{equation}
# \begin{equation}\label{eq:semiannual_compounding}
# r_{1} = C_{i} \times (1+\frac{r_{f}}{2})^{2}\quad \text{Semi-annual compounding}
# \end{equation}
# \begin{equation}\label{eq:monthly_compounding}
# r_{1} = C_{i} \times (1+\frac{r_{f}}{12})^{12}\quad \text{Monthly compounding}
# \end{equation}
# \begin{equation}\label{eq:continuous_compounding}
# r_{1} = C_{i} \times e^{r_{f}}\quad \text{Continuous compounding}
# \end{equation}
#
# Where \(r_{f}\) is the annual percentage return and \(C_{i}\) is the initial capital investment. Using these equations it can be calculated that, for the given scenario, the percentage return per annum is 10%, 9.76%, 9.56% and 9.53% for the annual, semi-annual, monthly and continuous compounding, respectively.
#
# Using equations 21 and 22, the relationship between monthly and continuous compounding is determined by:
#
# \begin{equation}\label{eq:rel_month_cont_comp}
# r_{f continuous} = ln((1+\frac{r_{f monthly}}{12})^{12})
# \end{equation}
#
# In this way, if the monthly compounding interest is of 15%, the equivalent continuous interest is 14.91%.
#
# An account with a deposit of 10,000 dollars and an annual continuous compounding interest of 12% that is paid quarterly can be calculated using the equation below. It will result in quarterly payments of 318.74 dollars.
#
# \begin{equation}\label{eq:quarterly_payment}
# payment = \frac{1}{4}\times (e^{0.12}-10000)
# \end{equation}

# %% [markdown]
# ## Forward rates
#
# If a one year interest is of 5% and a two year interest is of 7% for an investment of £100, the forward rate of interest equals 9%. This is the extra capital obtained on the initial investment over the two year period using the second investment strategy. The forward price can be calculated using the following equation:
#
# \begin{equation}\label{eq:forward_price}
# F = S_{0}e^{(r-q)T}
# \end{equation}
#
# Where \(F, S_{0}, r, q\) are the forward price, initial investment, interest rate and the cost of carry, respectively. With the current value of the dollar, and assuming no cost of carry, it makes little sense to make a 2 year 7% interest investment because in absolute values, the difference is very small and investment time period is of two years instead of one. If the initial investment capital was of a higher order, it would make more economic sense. They only reason to invest such a small amount of money is to avoid the devaluation caused by inflation or to reduce the risk of storing the capital somewhere else. It would, therefore, be more practical to make use of the first investment strategy with an annual interest rate of 5%. This gives the investor the flexibility to get back the money in a shorter amount of time and to decide whether or not to reinvest. If then cost of carry is assumed to be of 4%, both investments would give the same return but the second strategy would take twice the amount of time. Moreover, an assumption was made that the investment was free of risk. This is often not the case and it must be taken into account when selecting the investment strategy.
#
# For the second strategy to become the best option several certain requirements are need to be met. First, the annual inflation figures and risk of default must be known in order to aid in the selection of a cost of carry. Then the interest rate must be larger than this value and considerably larger than that of the first strategy for the reasons mentioned above.
#
#
# ## Duration of a coupon-bearing bond
#
# The duration of a bond is the weighted average of the times of each to the payments until the maturity date and it is described in the equation below. The duration is used to measure the sensitivity of any given bond to a change in the interest rates. Using this equation, the duration of a 1% bond can be found to be equal to 6.76.
#
# \begin{equation}\label{eq:duration}
# Duration = \sum_{i=1}^{T}\frac{t_{i}\times PV(C_{i})}{PV}
# \end{equation}
#
# A modified version of the duration is the volatility and it is used to measure the percentage change of the bond price with a one percent change in yield. It is defined in equation \ref{eq:modified_duration}. Using this expression, the modified duration is equal to 6.32.
#
# \begin{equation}\label{eq:modified_duration}
# \text{Modified duration}  = \text{volatiltiy (%)} = \frac{Duration}{1+yield}
# \end{equation}
#
# While the first expression for the duration is the weighted average time until repayment, the modified duration measures the sensitivity of the bond price with respect to the yield.
#
# Bond prices are susceptible to interest rates and have an inverse relationship. Therefore, when selecting a bond to carry the pension plan of an investor it is useful to understand how susceptible it is to changes in the interest rates. The modified duration can be used for this purpose. This information can also help determine whether to agree to a fixed or a floating interest rate. The first would have a higher relative yield in the case of the interest rates being lowered, and conversely, and the latter would fluctuate with them. This is, therefore, a risk/yield trade-off that the investor can for his/hers pension plan.

# %% [markdown]
# ## Capital Asset Pricing Model (CAPM) and Arbitrage Pricing Theory (APT)

# %% [markdown]
# ### Average of company returns
#
# In this section the daily market returns of 157 European companies are evaluated. First, the daily average return of the whole selected market is computed and shown below. Although the average return is positive, it is very low.

# %%
df = pd.read_csv(r'fsp_case_31_BSD.csv',index_col=0,header=[0,1]).fillna(0)
avg_returns = df['ret'].mean(axis=1)
# pdb.set_trace()
dates = df['ret'].index
date_axis = [dt.datetime.strptime(d,'%Y-%m-%d').date() for d in dates]

print('The average daily return of the whole market is ', avg_returns.mean())

plt.figure(dpi=100, figsize=(5,3))
plt.plot(date_axis, avg_returns)
plt.title('Average returns of 157 european companies')
plt.xticks(rotation=45)
plt.xlabel('dates')
plt.ylabel('average return')
plt.grid()
plt.show()
# Out:
# The average daily return of the whole market is  6.094780982187593e-05

# %% [markdown]
# ### Rolling beta
#
# It is of interest to study the effect of the expected excess asset returns to the expected excess market returns. If the market fluctuates, it can be estimated how individual assets will behave which will aid in the evaluation of risk. This is done through the calculation of \(\beta_{i}\), which is the ratio of the covariance of the individual asset and the market return over the variance of the return of the market. This parameter is calculated for the market currently under study. As it can be observed in the figure below, this parameter has a high fluctuation and cannot be assumed constant. The higher the \(\beta_{i}\), the more the returns will fluctuate when the market is volatile. On the other hand, if the beta is positive an smaller than 1, the value of the asset will tend to remain stable when the market fluctuates. A negative beta occurs when an asset tends to have an opposite behavior to the market. The selection of a portfolio is greatly determined by this parameter.

# %%
plt.figure(dpi=100, figsize=(5,3))
plt.title('Estimated rolling Beta for the 157 European companies')
plt.xlabel('date')
plt.ylabel('estimated Beta')
plt.grid()
betas = df['ret'].rolling(22).cov(avg_returns).dropna()/np.var(avg_returns)
plt.plot(betas.index, betas)
plt.xticks([betas.index[i] for i in np.linspace(0,len(betas.index)-1, 10).astype(int)],rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Capital weighted market return
#
# In the following exercise, the capital weighted market return is calculated. This computed as the sum of the returns of each of the stocks in the market times their capital valuation over the total market valuation. This approach gives more importance to the returns of stocks whose value is larger. A return of 1% of an asset whose value is low will not have the same effect on the market return as that of a large company.

# %%
total_mcap = df['mcap'].sum(axis=1)
df2 = pd.DataFrame()
df2['a'] = np.array(total_mcap)
asset_returns = np.divide(np.array(df['mcap']*df['ret']),np.array(total_mcap).reshape(-1,1))
market_return = np.sum(asset_returns, axis=1)

plt.figure(dpi=100, figsize=(5,3))
plt.title('Cap-weighted market return')
plt.xlabel('date')
plt.ylabel('return (%)')
plt.grid()
plt.plot(df.index, market_return*100)
plt.xticks([df.index[i] for i in np.linspace(0,len(betas.index)-1, 10).astype(int)],rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The figure below shows the individual asset weighting in the market.

# %%
plt.figure(dpi=100, figsize=(5,3))
plt.title('Cap-weighted asset return')
plt.xlabel('date')
plt.ylabel('return (%)')
plt.grid()
plt.plot(df.index, asset_returns*100)
plt.xticks([df.index[i] for i in np.linspace(0,len(betas.index)-1, 10).astype(int)],rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Capital weighted rolling beta
#
# Previously, a rolling \(\beta_{m}\) with a window of 22 days was computed using the equally weighted market return. In the following exercise, the cap-weighted market return will be computed to estimate the \(\beta_{m}\) with the same rolling window. As it can be seen in the figure below, the shape of these sensitivity parameters is very similar. However, the weighting gives a larger importance to fluctuations in the value of large companies. An investor would be very interested in this modification since these companies are the big drivers of the market valuation. For the rest of this section, the new computed \(\beta_{m}\) will be used.

# %%
plt.figure(dpi=100, figsize=(5,3))
plt.title('Cap-weighted market return rolling Beta')
plt.xlabel('date')
plt.ylabel('estimated Beta')
plt.grid()
df2 = pd.DataFrame()
df2['Market return'] = market_return
df2.index = df.index
betas = df['ret'].rolling(22).cov(df2['Market return']).dropna()/np.var(df2['Market return'])
plt.plot(betas.index, betas)
plt.xticks([betas.index[i] for i in np.linspace(0,len(betas.index)-1, 10).astype(int)],rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### APT for a two factor model
#
# In this exercise, the parameters of an arbitrage pricing model (APT) for two factors are estimated. This is a more complex model than the CAPM evaluated above and it can therefore be a better descriptor of the behavior of an assets value. However, it is also more difficult obtain the parameters since more data is required. The APM aims to study the influence from a series of factors in the return of an asset. For this exercise these factors are the cap-weighted market returns and the small minus big (SMB). The latter is a factor commonly used to describe the dependency of an assets return to it's absolute market value. In this exercise, the sensitivity to this factor is taken to be the natural logarithm of the market value of the asset. The equation describing the APT is:
#
# \begin{equation}\label{eq:}
# r_{i} = a + b_{m}R_{m} + b_{s}R_{s}+\epsilon_{i}
# \end{equation}
#
# where \(\epsilon_{i}\) is the specific return, \(a\) is the active return of the asset, \(b_{m}\) is the cap-weighted beta calculated before, \(R_{m}\) is the return of the market, \(b_{s}\) is the sensitivity to the size of the asset. The parameters that are to be estimated for each company and day are \(a, R_{m}\) and \(R_{s}\). These are shown in the figure below. \(\epsilon_{i}\) is computed as the difference between the predicted return and the actual return.

# %%
e = np.zeros((157, len(betas)))
bs = np.zeros((157, len(betas)))
r = np.zeros((157, len(betas)))
a = np.zeros(157)
coeffs = []
# coeffs = np.zeros((157, 3))
coeffs2 = np.zeros((157, 3))
df.replace([np.inf, -np.inf], np.nan)
df.fillna(0)
market_returns = np.zeros((157, len(betas)))

for i in range(157):
#     e[i,:] = np.random.normal(0, np.std(np.array(df['ret']).T[i]), len(betas))
    bs[i,:] = np.log(np.array(df['mcap']).T[i])[21:]
    r[i,:] = np.array(df['ret']).T[i][21:]
    a[i] = np.mean(r[i,:])
    market_returns[i] = market_return[21:]
    
X = np.array([market_returns,bs]).reshape(2,157,len(betas))

# The parameter a is constant throughout the time series for each company
y = r-a.reshape(-1,1)*np.ones(500)
scores = []
regs2 = []
for i in range(157):
    regs = []
    for t in range(500):
        exception = False
        try:
            reg = LinearRegression(fit_intercept=False).fit(X[:,i,t].reshape(-1,1).T,y[i,t].reshape(1))
            regs.append(reg)
            scores.append(reg.score(X[:,i].T,y[i]))
            coeffs.append([reg.intercept_, reg.coef_[0], reg.coef_[1]])
        # ValueError: Input contains NaN, infty or value too large for float64
        except Exception:
            exception = True
            pass
    if exception == False:
        regs2.append(regs)

# %%
# print('The average R^2 of the regression is ', np.mean(np.array(scores)))
plt.figure(dpi=100, figsize=(5,6))
plt.subplot(211)
plt.title('Average coefficients of the APT two factor model')
plt.xlabel('company number')
plt.grid()
plot1, = plt.plot(a, label='a')
Rm_company_mean = [np.mean([regs2[n][i].coef_[0] for i in range(len(regs2[0]))]) for n in range(len(regs2))]
plot2, = plt.plot(Rm_company_mean, label='Rm')
Rs_company_mean = [np.mean([regs2[n][i].coef_[1] for i in range(len(regs2[0]))]) for n in range(len(regs2))]
plot3, = plt.plot(Rs_company_mean, label='Rs')
plt.legend(handles=[plot1, plot2, plot3])
plt.tight_layout()

plt.subplot(212)
plt.title('Coefficients of the APT two factor model for G_AALLN')
plt.xlabel('time t')
plt.grid()
plot1, = plt.plot([regs2[0][i].coef_[1] for i in range(len(regs2[0]))],label='Rs')
plot2, = plt.plot([regs2[0][i].coef_[0] for i in range(len(regs2[0]))], label='Rm')
plot3, = plt.plot((a[0].reshape(-1,1)*np.ones(len(regs2[0]))).flatten(), label='a')
plt.legend(handles=[plot1, plot2, plot3])
plt.tight_layout()
plt.show()

# %%
std_a = np.std(np.array(a))
print('The mean and standard deviation of the parameter a are ', np.mean(np.array(coeffs)[:,0]), ' and ', std_a, ', respectively.')
Rm_company_std = np.mean(np.array([np.std([regs2[n][i].coef_[0] for i in range(len(regs2[0]))]) for n in range(len(regs2))]))
print('The mean and standard deviation of the parameter Rm are ', np.mean(Rm_company_mean), ' and ', Rm_company_std, ', respectively.')
Rs_company_std = np.mean(np.array([np.mean([regs2[n][i].coef_[0] for i in range(len(regs2[1]))]) for n in range(len(regs2))]))
print('The mean and standard deviation of the parameter Rs are ', np.mean(Rs_company_mean), ' and ', Rs_company_std, ', respectively.')
# Out:
# The mean and standard deviation of the parameter a are  0.0  and  0.000722314755628154 , respectively.
# The mean and standard deviation of the parameter Rm are  7.74626629547057e-08  and  2.4298123800300005e-07 , respectively.
# The mean and standard deviation of the parameter Rs are  -3.0026876840468974e-07  and  7.74626629547057e-08 , respectively.

# %% [markdown]
# Using the above evaluation it can be observed that the returns are more susceptible to the parameter \(R_{s}\) than to  \(a\) and \(R_{m}\). However \(R_{m}\) has a relatively high standard deviation.
#
# In the following exercise, the correlation through time of every company is calculated. This is equivalent to calculating the scalar product of the return and specific return vectors. The figure below shows that there is no time correlation between the two time series. Very little information can be extracted from previous returns in order to forecast the future.

# %%
corr = np.zeros((len(regs2),500))
e = np.zeros((len(regs2),500))
for i in range(len(regs2)):
    for n in range(500):
        try:
            e[i,n] = regs2[i][n].predict(X[:,i,n].reshape(-1,1).T)
            corr[i,n] = e[i,n]*r[i,n]
        except:
            pass
plt.title('Correlation through time of the specific return and the return')
plt.xlabel('time t')
plt.grid()
for i in range(141):
    plt.plot(corr[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# In this experiment the covariance of the matrix  \textbf{R}  is computed. The columns of \textbf{R} are constructed with the time series of the parameters \(R_{m}\) and \(R_{s}\). The results show that the magnitude of the covariance matrix is very small. It can also be stated that the matrix is stable due to the eigenvalues being smaller than 1.

# %%
Rm = np.array([regs2[0][i].coef_[0] for i in range(len(regs2[0]))])
Rs = np.array([regs2[0][i].coef_[1] for i in range(len(regs2[0]))])
R = np.array([Rm, Rs])
covR = np.cov(R)
eigR, eigvectR = np.linalg.eig(covR)
print('The eigenvectors of the covariance matrix are')
print(eigR)
print('The covariance matrix for the matrix R is ')
pd.DataFrame(covR)
# Out:
# The eigenvectors of the covariance matrix are
# [7.95905385e-14 7.47983654e-07]
# The covariance matrix for the matrix R is
#               0             1
# 0  7.966003e-14  7.209502e-12
# 1  7.209502e-12  7.479837e-07

# %% [markdown]
# A matrix \textbf{E} is constructed where each of the columns is the time series of the specific return \(\epsilon_{i}\) for each company \(i\). The covariance matrix for \textbf{E} is then computed and a principal component analysis is carried out. This is the dimensionality reduction process by which the vectors that maximize the variance of the data are found. It is useful when the aim is to obtain only the most relevant information in a dataset. The largest component of the matrix is 0.003509. By dividing by the sum of all the components it can be found that the percentage of variance that can be explained by the first component is 11.02%.

# %%
covE = np.cov(e)
eige, eigvecte = np.linalg.eig(covE)
pca = PCA(n_components=141)
pca.fit(covE)
print('The first component value is equal to ', pca.singular_values_[0])
print('The first principal component can explain ', 100*pca.singular_values_[0]/np.sum(pca.singular_values_),'% of the variance')
# print(pca.singular_values_/np.sum(np.diag(eige))*100)
# np.mean((2*np.ones((5,5)))/np.ones((5,5)))
# Out:
# The first component value is equal to  0.003509192224861148
# The first principal component can explain  11.018316780663012 % of the variance

# %% [markdown]
# # Portfolio Optimization

# %% [markdown]
# ## Adaptive minimum-variance portfolio optimization
#
# ### Derivation of the minimum-variance portfolio
#
# An investor will look to minimize the variance of his/her portfolio in order to reduce the risk of the overall investment. This can be achieved by selecting a set of assets whose covariance is low. In this exercise, the minimum variance portfolio is studied. This is an optimization problem whose objective function minimizes the portfolio variance subject to the condition of the sum of the weights to be equal to one. The equation is shown below (black font equations don't compile on the jupyter notebook):

# %% [markdown]
# \begin{equation}
# min_{w} \frac{1}{2}w^{T}Cw
# \end{equation}
# subject to
# \begin{equation}
# w^{T}1 = 1
# \end{equation}
#
# Using the lagrange multipliers the problem to solve becomes:
#
# \begin{equation}
# min_{w,\lambda} J'(w,\lambda, C) = \frac{1}{2}w^{T}Cw - \lambda(w^{T}1 - 1)
# \end{equation}
#
# By taking the gradient with respect to \(w\) and \(\lambda\) a system of two equations is constructed.
#
# \begin{equation}\label{eq:system_eq_1}
# wC - \lambda 1^{T}
# \end{equation}
# \begin{equation}\label{eq:system_eq_2}
# w^{T}1 - 1 = 0
# \end{equation}
#
# Rearranging Eq. \ref{eq:system_eq_1} leads to
#
# \begin{equation}
# w^{T} = \lambda1^{T}C^{-1}\\
# \end{equation}
# \begin{equation}
# w^{T}1 = \lambda1^{T}C^{-1}1
# \end{equation}
#
#
# And using Eq. \ref{eq:system_eq_2} converts the equation into:
#
# \begin{equation}
# 1 = \lambda1^{T}C^{-1}1\\
# \end{equation}
#
# Solving for \(\lambda\) results in:
#
# \begin{equation}\label{eq:solution_lambda}
# \lambda = \frac{1}{1^{T}C^{-1}1}
# \end{equation}
#
# Finally, substituting Eq.\ref{eq:solution_lambda} into Eq.\ref{eq:system_eq_1} gives the result for the optimal weights:
#
# \begin{equation}\label{eq:solution_w}
# T  = \frac{1^{T}C^{-1}}{1^{T}C^{-1}1}
# \end{equation}
#
# When employing the optimal weights in Eq.\ref{eq:solution_w} for the construction of a portfolio, the mean and variance of its set of securities become:
#
# \begin{equation}
# \hat{\mu} = (\frac{1^{T}C^{-1}}{1^{T}C^{-1}1})^{T}\mu
# \end{equation}
#
# \begin{equation}
# \hat{\sigma}^{2} = \frac{1^{T}}{1^{T}C^{-1}1}(\frac{1^{T}C^{-1}}{1^{T}C^{-1}1})^{T}
# \end{equation}

# %% [markdown]
# ### Performance of a portfolio with two strategies
#
# In this exercise, two different strategies are employed: the minimum variance portfolio and the equally weighted portfolio. The first constructs a portfolio using Eq.\ref{eq:solution_w}. This way, the volatility of the portfolio is minimized. However, this does not mean that returns will be higher. The second strategy gives the same weighting to all the assets in the market, with the sum being equal to one. In order to select the weights, a training dataset is constructed with the first half of the whole time series. The rest of the dataset is used for testing the portfolio selection. Other strategies for the train/test split could have been used such as a random selection of the datapoints. However, it as assumed that the investor will be looking at the whole time series from the past whenever creating his/her portfolio.
#
# The results are shown below. It can be observed that variance is significantly reduced when using a minimum variance portfolio over an equally weighted one. Although both cumulative returns are negative, the ones from the minimum variance portfolio are slightly better. The figure below displays the time series of the cumulative return of both strategies. For half the time period, the equally weighted strategy yielded positive returns until it quickly decreased. Om the other hand, the minimum variance strategy consistently yielded negative returns but with a lower volatility. The figure illustrates the aim of the minimum variance strategy i.e reduce the volatility. Since the optimization problem had no incentive to look for assets whose returns where positive, this strategy does not necessarily lead to higher returns.

# %%
df = pd.read_csv(r'fsp_case_31_BSD.csv',index_col=0,header=[0,1]).fillna(0)
ret = np.array(df['ret']).T
train_r = ret[:,:int(521/2)]
test_r = ret[:,int(521/2):]

C = np.cov(train_r)
C_inv = np.linalg.inv(C)
ones = np.ones(C.shape[0]).reshape(-1,1)

w_opt = ((np.dot(ones.T,C_inv))/np.dot(np.dot(ones.T,C_inv),ones)).T
w_2 = np.ones(C.shape[0])*(1/C.shape[0])

r_opt = np.array([np.dot(w_opt.T,test_r[:,n]) for n in range(test_r.shape[1])])
r_2 = np.array([np.dot(w_2.T,test_r[:,n]) for n in range(test_r.shape[1])])
R_opt = np.cumsum(r_opt)
R_2 = np.cumsum(r_2)
print('The return of the minimum variance weights is ', R_opt[-1])
print('The variance of the minimum variance weights is ', np.var(r_opt))
print('The return of the equally weighted portfolio is ', R_2[-1])
print('The variance of the equally weighted portfolio is ', np.var(r_2))

plt.figure(dpi=100, figsize=(5,3))
plt.plot(dates[int(521/2):],R_opt)
plt.plot(dates[int(521/2):],R_2)
plt.xticks([dates[int(i)] for i in list(np.linspace(int(521/2),520,15))], rotation=45)
plt.grid()
plt.xlabel('date')
plt.ylabel('cumulative return')
plt.title('Cumulative return of the optimal and equal weights portfolios')
plt.legend(['MV weights', 'Equal weights'])
plt.tight_layout()
plt.show()
# Out:
# The return of the minimum variance weights is  -0.07528460678015485
# The variance of the minimum variance weights is  5.553116789182464e-06
# The return of the equally weighted portfolio is  -0.11410908280254783
# The variance of the equally weighted portfolio is  5.123941984264214e-05

# %% [markdown]
# ### Adaptive time-varying minimum variance portfolio
#
# An adaptive time-varying minimum variance portfolio can be achieved by computing a time varying inverse covariance matrix with a rolling window. This way, the the optimal weights can be recomputed at every time step depending on how the securities are fluctuating. Intuitively, this approach should yield a higher performance than the static MV and equally weighted portfolios because the algorithm could correct for any changes in the market. However, it would also only be able to use a smaller amount of data-points which is determined by the window size.
#
# In this experiment this approach is followed. However, as can be observed by computing the listing below, when the inverse of the covariance matrix is computed, a matrix that is not full rank is returned. The determinant of such a matrix is 0 and the inverse used for computing the weights cannot be calculated. For this reason, the performance of this algorithm could not be evaluated.

# %%
M = 22
C_roll = np.zeros((157,157,500))
C_roll_inv = np.zeros((157,157,500))

for t in range(M, ret.shape[1]+1):
    try:
        C_roll[:,:,t-M] = np.cov(ret[:,t-M:t])
        C_roll_inv[:,:,t-M] = np.linalg.inv(C_roll[:,:,t-M])
    except Exception as e:
        print(e)
        break
# Out:
# Singular matrix

# %% [markdown]
# # Robust Statistics and Non Linear Methods
#
# ## Data Import and Exploratory Data Analysis
#
# In this section the statistics of the stock prices of Apple, IBM and JP. Morgan will be studied. Moreover, the effect of outliers in these statistics will be evaluated.
#
# ### Importing data and evaluating the statistics
#
# In order to process the stock prices it must first be imported from Yahoo Finance and stored into a pandas data-frame. The acquired data contains information on the opening, closing, high, low and adjusted close price from the 16th of March of 2018 to the 11 of March of 2019. The adjusted closing price is the closing price that takes into account share splits.
#
# The mean, median and standard deviation are then calculated for each of the columns of the data-frame. They are displayed in the listing below. Finally, the daily return of the adjusted close column is calculated and appended to the data-frame.

# %%
start = dt.datetime(2018, 3, 16)
end = dt.datetime(2019, 3, 11)
aapl = web.DataReader("aapl", 'yahoo', start, end)
ibm = web.DataReader("ibm", 'yahoo', start, end)
jpm = web.DataReader("jpm", 'yahoo', start, end)
dji = web.DataReader("^dji", 'yahoo', start, end)

stats = pd.DataFrame()
for column in ibm.columns:
    stats['Mean ' + column] = [aapl[column].mean(), ibm[column].mean(), jpm[column].mean(), dji[column].mean()]
    stats['Median ' + column] = [aapl[column].median(), ibm[column].median(), jpm[column].median(), dji[column].median()]
    stats['Std ' + column] = [aapl[column].std(), ibm[column].std(), jpm[column].std(), dji[column].std()]
stats.index = ['AAPL', 'IBM', 'JPM', 'DJI']
stats = stats.T
print(stats)

# Calculate the returns from the adjusted close
aapl['Ret'] = aapl.pct_change()['Adj Close'].fillna(0)
ibm['Ret'] = ibm.pct_change()['Adj Close'].fillna(0)
jpm['Ret'] = jpm.pct_change()['Adj Close'].fillna(0)
dji['Ret'] = dji.pct_change()['Adj Close'].fillna(0)
# Out:
#                           AAPL           IBM           JPM           DJI
# Mean High         1.896462e+02  1.394908e+02  1.097175e+02  2.513166e+04
# Median High       1.878100e+02  1.440800e+02  1.107300e+02  2.510639e+04
# Std High          2.245084e+01  1.200936e+01  5.218206e+00  8.175788e+02
# Mean Low          1.858913e+02  1.373143e+02  1.077370e+02  2.483394e+04
# Median Low        1.851000e+02  1.421800e+02  1.078100e+02  2.485709e+04
# Std Low           2.217951e+01  1.230267e+01  5.459230e+00  9.055440e+02
# Mean Open         1.877666e+02  1.384518e+02  1.087730e+02  2.499055e+04
# Median Open       1.863500e+02  1.429300e+02  1.094500e+02  2.500882e+04
# Std Open          2.231469e+01  1.221223e+01  5.377210e+00  8.615832e+02
# Mean Close        1.877864e+02  1.383566e+02  1.086637e+02  2.498774e+04
# Median Close      1.864400e+02  1.430000e+02  1.090900e+02  2.501941e+04
# Std Close         2.233088e+01  1.212529e+01  5.322690e+00  8.612331e+02
# ...

# %% [markdown]
# ### PDF of the adjusted close and the returns
#
# In signal processing the visualization of the pdf of sample data belonging to some distribution is done through the plot of a histogram. A histogram is a sequence of bins that have a data range and their value corresponds to the number of occurrences of the distribution in the bin. In this exercise, the histogram of both the adjusted close prices and the returns are displayed.
#
# It can be observed that all the returns follow a normal distribution with a positive mean and a low standard deviation. On the other hand, the adjusted close prices appear to have two clusters of bins. This could be interpreted as a distribution that is the sum of two normal distributions. If these pdfs were time-varying, this sum of gaussian distributions would become one single normal distribution whose mean and variance change with time.

# %%
plt.figure(dpi=100, figsize=(6,8))
for i in range(8):
    plt.subplot(4,2,i+1)
    plt.ylabel('bin value')
    plt.grid()
    plt.tight_layout()
    if i%2 == 0:
        plt.xlabel('return')
        column = 'Ret'
        string = 'Returns'
    else:
        plt.xlabel('Adj Close')
        column = 'Adj Close'
        string = 'Adjusted close'
    if i == 0 or i == 1:
        plt.title(str(string + ' of Apple'))
        aapl[column].hist().plot()
    if i == 2 or i == 3:
        plt.title(str(string + ' of IBM'))
        ibm[column].hist().plot()
    if i == 4 or i == 5:
        plt.title(str(string + ' of JPM'))
        jpm[column].hist().plot()
    if i == 6 or i == 7:
        plt.title(str(string + ' of DJI'))
        dji[column].hist().plot()
plt.show()

# %% [markdown]
# ### Rolling mean, median and standard deviations
#
# In this exercise a 5-day rolling mean and median are computed for the adjusted close prices of the three stocks. Moreover, the \(\pm 1.5\sigma\) standard deviation relative to the mean and the \(\pm 1.5 \) MAD (median absolute deviation) relative to the median are calculated. These are all displayed in the figures below.
#
# The region that is outside the \(\pm 1.5\sigma \) is considered the outlier region because the probability of a point lying outside it in a normal distribution is of 0.07% (very difficult). The results show that the difference between the mean and median are very small. These two metrics resemble each other when the distribution of the time series is gaussian. This finding does not agree with the probability distributions evaluated in the previous section because they are not time-varying. The locations at which the mean and median deviate the most are those in which there is a significant positive or negative trend. Robust estimators are, therefore, only reliable when the distributions are normal and there is a large number of samples.
#
# The rolling mean and median smooth out the time-series and, therefore, make the evaluation of the performance of a stock less susceptible to noise. The calculation of the standard deviation and the median absolute deviation are both taken using a rolling window of 5 days over the mean and median metrics, respectively. It can be observed that the standard deviation region is wider than that of the median absolute deviation. This is due to the fact that the median metric is a robust estimator and in a normal distribution is less susceptible to data-points far away from it. For the standard deviation, the distance to the mean is squared, therefore, outliers impact significantly the shape of the function.

# %%
roll_mean_aapl = aapl['Adj Close'].rolling(5).mean()
roll_mean_ibm = ibm['Adj Close'].rolling(5).mean()
roll_mean_jpm = jpm['Adj Close'].rolling(5).mean()

roll_median_aapl = aapl['Adj Close'].rolling(5).median()
roll_median_ibm = ibm['Adj Close'].rolling(5).median()
roll_median_jpm = jpm['Adj Close'].rolling(5).median()

roll_mad_aapl = np.array([robust.mad(roll_median_aapl[t:t+5]) for t in range(4, len(roll_median_aapl)-5)])
roll_mad_ibm = np.array([robust.mad(roll_median_ibm[t:t+5]) for t in range(4, len(roll_median_ibm)-5)])
roll_mad_jpm = np.array([robust.mad(roll_median_jpm[t:t+5]) for t in range(4, len(roll_median_jpm)-5)])


plt.figure(dpi=100, figsize=(6,8))
plt.subplot(211)
plt.ylabel('Adj Close')
plt.xlabel('date')
plt.title('5 day rolling Adj Close mean and +/-1.5 sigma std region')
plt.tight_layout()

plt.plot(roll_mean_aapl,'red', label='AAPL', linewidth=0.8)
plt.plot(aapl['Adj Close'], 'black', linewidth=0.8)
a, = plt.plot(aapl.index, [None]*len(aapl.index),color='blue', label='AAPL')
plt.fill_between(aapl.index,roll_mean_aapl.rolling(5).std()*1.5+roll_mean_aapl , -roll_mean_aapl.rolling(5).std()*1.5+roll_mean_aapl, color='blue', alpha=0.7)

plt.plot(roll_mean_ibm,'red', label='IBM', linewidth=0.8)
plt.plot(ibm['Adj Close'], 'black', linewidth=0.8)
b, = plt.plot(ibm.index, [None]*len(ibm.index),color='orange', label='IBM')
plt.fill_between(ibm.index,roll_mean_ibm.rolling(5).std()*1.5+roll_mean_ibm , -roll_mean_ibm.rolling(5).std()*1.5+roll_mean_ibm, color='orange', alpha=0.7)

plt.plot(roll_mean_jpm,'red', label='JPM', linewidth=0.8)
plt.plot(jpm['Adj Close'], 'black', linewidth=0.8)
c, = plt.plot(jpm.index, [None]*len(jpm.index),color='green', label='JPM')
plt.fill_between(jpm.index,roll_mean_jpm.rolling(5).std()*1.5+roll_mean_jpm , -roll_mean_jpm.rolling(5).std()*1.5+roll_mean_jpm, color='green', alpha=0.7)

d, = plt.plot(aapl.index, [None]*len(aapl.index), color='black', label='Adj Close')
e, = plt.plot(aapl.index, [None]*len(aapl.index), color='red', label='Mean')

plt.xticks(rotation=45)
plt.tight_layout()
plt.grid()
plt.legend(handles=[a,b,c,d,e])

plt.subplot(212)
plt.ylabel('Adj Close')
plt.xlabel('date')
plt.title('5 day rolling Adj Close median and +/-1.5 mad region')

plt.plot(roll_median_aapl,'red', label='AAPL', linewidth=0.8)
plt.plot(aapl['Adj Close'], 'black', linewidth=0.8)
a, = plt.plot(aapl.index, [None]*len(aapl.index),color='blue', label='AAPL')
plt.fill_between(aapl.index[9:],roll_mad_aapl*1.5+roll_median_aapl[9:] , -roll_mad_aapl*1.5+roll_median_aapl[9:], color='blue', alpha=0.7)

plt.plot(roll_median_ibm,'red', label='IBM', linewidth=0.8)
plt.plot(ibm['Adj Close'], 'black', linewidth=0.8)
b, = plt.plot(ibm.index, [None]*len(ibm.index),color='orange', label='IBM')
plt.fill_between(ibm.index[9:],roll_mad_ibm*1.5+roll_median_ibm[9:] , -roll_mad_ibm*1.5+roll_median_ibm[9:], color='orange', alpha=0.7)

plt.plot(roll_median_jpm,'red', label='JPM', linewidth=0.8)
plt.plot(jpm['Adj Close'], 'black', linewidth=0.8)
c, = plt.plot(jpm.index, [None]*len(jpm.index),color='green', label='JPM')
plt.fill_between(jpm.index[9:],roll_mad_jpm*1.5+roll_median_jpm[9:] , -roll_mad_jpm*1.5+roll_median_jpm[9:], color='green', alpha=0.7)

d, = plt.plot(aapl.index, [None]*len(aapl.index), color='black', label='Adj Close')
e, = plt.plot(aapl.index, [None]*len(aapl.index), color='red', label='Median')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid()
plt.legend(handles=[a,b,c,d,e])
plt.show()

# %% [markdown]
# ### Introducing outliers
#
# It is of interest to evaluate the behavior of the statistical metrics from the previous section with the presence of outliers. For this reason, 4 data-points equal to the maximum value of the time-series multiplied by 1.2 are assigned to the stock values whose dates are: 2018-05-14, 2018-09-14, 2018-12-14 and 2019-01-14.
# When visualizing the plots below, it is clear that, for the mean, there are sudden jumps in the price of the stocks in those dates. However, since the metrics are computed with a rolling window of 5 days, these outliers are smoothed out. On the other hand, the median is less susceptible to outliers and so the median absolute deviation is not as wide as the standard deviation of the mean for the same dates.

# %%
aapl2 = aapl.copy()
ibm2 = ibm.copy()
jpm2 = jpm.copy()

for i in [40, 126, 189, 208]:
    aapl2.set_value(aapl2.index[i],'Adj Close',1.2*aapl['Adj Close'].max())
    ibm2.set_value(ibm2.index[i],'Adj Close',1.2*ibm['Adj Close'].max())
    jpm2.set_value(jpm2.index[i],'Adj Close',1.2*jpm['Adj Close'].max())

roll_mean_aapl2 = aapl2['Adj Close'].rolling(5).mean()
roll_mean_ibm2 = ibm2['Adj Close'].rolling(5).mean()
roll_mean_jpm2 = jpm2['Adj Close'].rolling(5).mean()

roll_median_aapl2 = aapl2['Adj Close'].rolling(5).median()
roll_median_ibm2 = ibm2['Adj Close'].rolling(5).median()
roll_median_jpm2 = jpm2['Adj Close'].rolling(5).median()

roll_mad_aapl2 = np.array([robust.mad(roll_median_aapl2[t:t+5]) for t in range(4, len(roll_median_aapl)-5)])
roll_mad_ibm2 = np.array([robust.mad(roll_median_ibm2[t:t+5]) for t in range(4, len(roll_median_ibm)-5)])
roll_mad_jpm2 = np.array([robust.mad(roll_median_jpm2[t:t+5]) for t in range(4, len(roll_median_jpm)-5)])

plt.figure(dpi=100, figsize=(6,8))
plt.subplot(211)
plt.ylabel('Adj Close')
plt.xlabel('date')
plt.title('5 day rolling Adj Close mean and +/-1.5 sigma std region with outliers')
plt.tight_layout()

plt.plot(roll_mean_aapl2,'red', label='AAPL', linewidth=0.8)
plt.plot(aapl2['Adj Close'], 'black', linewidth=0.8)
a, = plt.plot(aapl2.index, [None]*len(aapl2.index),color='blue', label='AAPL')
plt.fill_between(aapl2.index,roll_mean_aapl2.rolling(5).std()*1.5+roll_mean_aapl2 , -roll_mean_aapl2.rolling(5).std()*1.5+roll_mean_aapl2, color='blue', alpha=0.7)

plt.plot(roll_mean_ibm2,'red', label='IBM', linewidth=0.8)
plt.plot(ibm2['Adj Close'], 'black', linewidth=0.8)
b, = plt.plot(ibm2.index, [None]*len(ibm2.index),color='orange', label='IBM')
plt.fill_between(ibm2.index,roll_mean_ibm2.rolling(5).std()*1.5+roll_mean_ibm2 , -roll_mean_ibm2.rolling(5).std()*1.5+roll_mean_ibm2, color='orange', alpha=0.7)

plt.plot(roll_mean_jpm2,'red', label='JPM', linewidth=0.8)
plt.plot(jpm2['Adj Close'], 'black', linewidth=0.8)
c, = plt.plot(jpm2.index, [None]*len(jpm2.index),color='green', label='JPM')
plt.fill_between(jpm2.index,roll_mean_jpm2.rolling(5).std()*1.5+roll_mean_jpm2 , -roll_mean_jpm2.rolling(5).std()*1.5+roll_mean_jpm2, color='green', alpha=0.7)

d, = plt.plot(aapl2.index, [None]*len(aapl2.index), color='black', label='Adj Close')
e, = plt.plot(aapl2.index, [None]*len(aapl2.index), color='red', label='Mean')

plt.xticks(rotation=45)
plt.tight_layout()
plt.grid()
plt.legend(handles=[a,b,c,d,e])

plt.subplot(212)
plt.ylabel('Adj Close')
plt.xlabel('date')
plt.title('5 day rolling Adj Close median and +/-1.5 mad region with outliers')

plt.plot(roll_median_aapl2,'red', label='AAPL', linewidth=0.8)
plt.plot(aapl2['Adj Close'], 'black', linewidth=0.8)
a, = plt.plot(aapl2.index, [None]*len(aapl2.index),color='blue', label='AAPL')
plt.fill_between(aapl2.index[9:],roll_mad_aapl2*1.5+roll_median_aapl2[9:] , -roll_mad_aapl2*1.5+roll_median_aapl2[9:], color='blue', alpha=0.7)

plt.plot(roll_median_ibm2,'red', label='IBM', linewidth=0.8)
plt.plot(ibm2['Adj Close'], 'black', linewidth=0.8)
b, = plt.plot(ibm2.index, [None]*len(ibm2.index),color='orange', label='IBM')
plt.fill_between(ibm2.index[9:],roll_mad_ibm2*1.5+roll_median_ibm2[9:] , -roll_mad_ibm2*1.5+roll_median_ibm2[9:], color='orange', alpha=0.7)

plt.plot(roll_median_jpm2,'red', label='JPM', linewidth=0.8)
plt.plot(jpm2['Adj Close'], 'black', linewidth=0.8)
c, = plt.plot(jpm2.index, [None]*len(jpm2.index),color='green', label='JPM')
plt.fill_between(jpm2.index[9:],roll_mad_jpm2*1.5+roll_median_jpm2[9:] , -roll_mad_jpm2*1.5+roll_median_jpm2[9:], color='green', alpha=0.7)

d, = plt.plot(aapl2.index, [None]*len(aapl2.index), color='black', label='Adj Close')
e, = plt.plot(aapl2.index, [None]*len(aapl2.index), color='red', label='Median')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid()
plt.legend(handles=[a,b,c,d,e])
plt.show()

# %% [markdown]
# ### Box plot of the stocks
#
# A box plot is an illustration of the distribution of a dataset. It is made out of a whisker and a box. The first is located at the extremes of the distribution and it contains the first and fourth quartiles. The latter spans the second and third quartiles and contains a line that represents the median. Additionally, it can also contain bubbles that show the occurrence of outliers. This type of plot is very useful for comparing different distributions. It can give very important insight, such as symmetry of the distribution, tail length, centrality and spread.
#
# For this exercise, a box plot is displayed for the adjusted close prices of Apple, IBM and JP. Morgan from March 2018 to March 2019. From the observations in the figure below it can be stated that the distribution of the Apple stock price normally valued closer to its minimum than to its maximum due to the median being in the lower side of the box. Moreover, it can be seen that it is very long tailed. Apple stock prices have changed significantly over the course of one year and this is reflected in the size of the whiskers. Finally, it can be observed that the distribution  is overall symmetric. This agrees with the stock price figure in the above section due to its resemblence with a distorted sinusoid.
#
# The IBM distribution has a high median with respect to its distribution: IBM was mostly stable at high values until taking a dip in October 2019. For the same reason it is not very symmetric.
#
# Finally, the JP. Morgan stock price stands out for its low spread. It is also very centered, with a larger tail towards lower values. This distribution also contains one detected outlier at the bottom end of the lower whisker.

# %%
plt.figure(dpi=100, figsize=(5,3))
plt.ylabel('Adj Close')
plt.xlabel('stock')
plt.title('Box plot of AAPL, IBM and JPM')
plt.grid()
plt.boxplot([aapl['Adj Close'],ibm['Adj Close'],jpm['Adj Close']])
plt.xticks(range(1,4),['AAPL', 'IBM', 'JPM'])
plt.show()

# %% [markdown]
# ## Robust Estimators
#
# In this section three estimators (i.e median, interquartile range and median absolute deviation) will be evaluated. They are characterized by being robust. This means that it is more difficult for the estimators to be wrong in the presence of outliers if the the sample distribution is gaussian.
#
# ### Estimator functions
#
# Three functions are written and each of them computes the above mentioned estimators. These can be seen in the listing below.

# %%
def median(df):
    return df.median()

def iqr(df):
    return np.array(df.quantile([0.25,0.75]))

def mad(df):
    return robust.mad(df.values)

# %% [markdown]
# ### Efficiency
#
# In this exercise, the statistical efficiency of each of the estimators will be assessed by investigating how many samples an estimator requires to obtain the theoretical result up until the third decimal. Each of the estimators evaluates an array of size \(N\) containing random samples from a gaussian distribution of mean 0 and unity standard deviation. For each value of \(N\), the mean of 10,000 iterations is computed. If this value is not accurate to the third decimal, \(N\) is increased by 10. The final \(N\) will tell the number of samples that are required on average to compute an accurate result. Using the code below it can be observed that on average, the median, IQR and MAD estimators require 1260, 2280 and 1800 samples in order to be sufficiently accurate to the third decimal. From these findings it can be said that the most efficient estimator is the median, followed by the MAD and IQR. This result disagrees with [1](http://web.ipac.caltech.edu/staff/fmasci/home/astro_refs/BetterThanMAD.pdf), which says that the least efficient estimator is MAD.

# %%
df = pd.DataFrame()
M = 10000
N = 200
np.random.seed(1234)
df['normal'] = np.random.normal(0,1,N)

estimate = 9999
while round(estimate,3) != 0:
    df = pd.DataFrame()
    df['normal'] = np.random.normal(0,1,N)
    for i in range(M):
        estimate = estimate + median(df['normal'][:N])
    estimate = estimate / M
    N = N + 20
N_median = N - 20
print('It takes ' + str(N_median) + ' samples for the median estimator to be accurate')

N = 200
estimate = [9999,9999]
while (round(estimate[0],3) != -0.67) and (round(estimate[1],3) != 0.67):
    df = pd.DataFrame()
    df['normal'] = np.random.normal(0,1,N)
    for i in range(M):
        estimate = estimate + iqr(df['normal'][:N])
    estimate = estimate / M
    N = N + 20
N_iqr = N - 20
print('It takes ' + str(N_iqr) + ' samples for the IQR estimator to be accurate')

N = 200
estimate = 9999
while round(estimate,3) != 1:
    df = pd.DataFrame()
    df['normal'] = np.random.normal(0,1,N)
    for i in range(M):
        estimate = estimate + mad(df['normal'][:N])
    estimate = estimate / M
    N = N + 20
N_mad = N - 20
print('It takes ' + str(N_mad) + ' samples for the MAD estimator to be accurate')
# Out:
# It takes 1260 samples for the median estimator to be accurate
# It takes 2280 samples for the IQR estimator to be accurate
# It takes 1800 samples for the MAD estimator to be accurate

# %% [markdown]
# Additionally, the computational efficiency of the three estimators will be evaluated using the IBM closing stock price from January 2010 to April 2019. The figure below displays the amount of time it takes for each of the functions to compute the estimator for N number of samples. Each observation is averaged over ten iterations in order to provide a more reliable result.
#
# The fastest estimator function is the median with an approximate computation time of 7 \(\mu s\). This function is followed then by the MAD function, which takes approximately 12 \(\mu s\). Finally, the slowest estimator function is the IQR. This function takes an average of 25 \(\mu s\) to compute. It can be observed that there is a slight linear relationship between the number of samples N and the computation time. It is to be expected that if the number of samples grows, so will the time it takes for the estimator to be computed.

# %%
ibm3 = web.DataReader("ibm", 'yahoo')

median_time = np.zeros(len(ibm3['Close']))
iqr_time = np.zeros(len(ibm3['Close']))
mad_time = np.zeros(len(ibm3['Close']))

for i in range(0,10):
    for n in range(1,len(ibm3['Close'])+1):
        time1 = time.time()
        median(ibm3['Close'][:n])
        time2 = time.time()
        iqr(ibm3['Close'][:n])
        time3 = time.time()
        mad(ibm3['Close'][:n])
        time4 = time.time()
        median_time[n-1] = median_time[n-1] + time2 - time1
        iqr_time[n-1] = iqr_time[n-1] + time3 - time2
        mad_time[n-1] = mad_time[n-1] + time4 - time3

median_time = 1000*median_time/len(ibm3['Close'])
iqr_time = 1000*iqr_time/len(ibm3['Close'])
mad_time = 1000*mad_time/len(ibm3['Close'])

plt.figure(dpi=100, figsize=(5,3))
plt.plot(range(1,len(median_time)+1), median_time)
plt.plot(range(1,len(iqr_time)+1), iqr_time)
plt.plot(range(1,len(mad_time)+1), mad_time)
plt.title('Computation time for three estimators')
plt.xlabel('N')
plt.ylabel('time (ms)')
plt.legend(['Median', 'IQR', 'MAD'])
plt.grid()
plt.show()

# %% [markdown]
# ### Breakdown point of the estimators
#
# The breakdown point of an estimator is the percentage of outliers that can be present in the sample data without making the estimator give an arbitrarily wrong value. It is a test to the robustness of any estimator. Since it is required for a corrupt sample size to be less than 50% of the total data in order to be classified as an outlier, it is also the maximum breakdown point. Two types of breakdown points can be studied, the finite sample and the asymptotic breakdown point [1](http://www.stat.umn.edu/geyer/5601/notes/break.pdf). The first is the breakdown point of the function with \(N\) number of samples and the latter has the \(N\) tend to infinity.
#
# For the median estimator, if a minority of data-points are outliers, the finite sample breakdown point is given by:
#
# \begin{equation}\label{eq:finite_b_median}
# floor(\frac{n-1}{2n})
# \end{equation}
#
# where \(n\) is the number of samples. For the asymptotic breakdown point, this function is equal to 0.5. As robust as the estimator can be.
#
# The IQR estimator is a translated version of two medians for the first and third quartiles. For this reason, the number of outliers needed to give an arbitrarily wrong estimate is half than that of the median, i.e 0.25 breakdown point.
#
# In order to test these theoretical results, an array of size \(N\), whose elements belong to a gaussian distribution with zero mean and unity standard deviation, are stacked to another array of size \(N-n\) with arbitrarily large values. The total size of the array is then \(2N-n\). With \(n\) varying from 0 to \(N\), each of the estimator functions computes the input array. If the estimate is within a reasonable distance to the theoretical result, the estimator has neglected the outliers of the distribution. This way it can be determined how many samples are needed to corrupt the estimate of the distribution and the breakdown point can be evaluated. The results below show that the breakdown points of the median, IQR and MAD estimators are 0.5, 0.25 and 0.49, respectively. These results agree with the theoretical estimates derived in this section.

# %%
N = 2000
deviation = 5
th_estimate = 0
gauss = np.random.normal(0,1,N)
for n in range(0,N):
    dist = pd.DataFrame()
    dist['stack'] = np.hstack((gauss, np.ones(N-n)*1000))
    estimate = median(dist['stack'])
    if estimate < (th_estimate + deviation):
        print('Breakdown point of the median estimator is', str(round((N-n)/(2*N-n),2)), '.')
        break
        
th_estimate = [-0.67, 0.67]
gauss = np.random.normal(0,1,N)
for n in range(0,N):
    dist = pd.DataFrame()
    dist['stack'] = np.hstack((gauss, np.ones(N-n)*1000))
    estimate = iqr(dist['stack'])
    if estimate[0] > (th_estimate[0] - deviation) and estimate[1] < (th_estimate[1] + deviation):
        print('Breakdown point of the IQR estimator is ', str(round((N-n)/(2*N-n),2)), '.')
        break
        
th_estimate = 1
gauss = np.random.normal(0,1,N)
for n in range(0,N):
    dist = pd.DataFrame()
    dist['stack'] = np.hstack((gauss, np.ones(N-n)*1000))
    estimate = mad(dist['stack'])
    if estimate < (th_estimate + deviation):
        print('Breakdown point of the MAD estimator is ', str(round((N-n)/(2*N-n),2)), '.')
        break
# Out:
# Breakdown point of the median estimator is 0.5 .
# Breakdown point of the IQR estimator is  0.25 .
# Breakdown point of the MAD estimator is  0.49 .

# %% [markdown]
# ## Robust and OLS Regression
#
# ### OLS daily returns regression of stocks against DJI
#
# In this exercise, the Ordinary Least Squares (OLS) regression is computed for the daily returns of Apple, IBM and JPM against those of the DJI. OLS minimizes the sum of the squares of the distances between the dataset and the predicted linear function. The figures below illustrate the result of the regression. The R squared error is defined as the proportion of the variance of the dependent variable \(y\) that can be explained by the independent variable \(x\). For each of the stocks the error is 0.51887, 0.41859 and 0.55649, respectively.

# %%
clf = LinearRegression()

y = dji['Ret']
plt.figure(dpi=100, figsize=(12,4))
x_axis = np.linspace(-0.1,0.1,len(ibm['Ret'])).reshape(-1,1)
i = 0
companies = ['AAPL', 'IBM', 'JPM']
titles = ['Apple vs DJI OLS regression', 'IBM vs DJI OLS regression', 'JPM vs DJI OLS regression']
for X in [np.array(aapl['Ret']).reshape(-1,1), np.array(ibm['Ret']).reshape(-1,1), np.array(jpm['Ret']).reshape(-1,1)]:
    clf=clf.fit(X, y)
    plt.subplot(1,3,i+1)
    plt.scatter(X,y)
    plt.plot(x_axis, x_axis * clf.coef_ + clf.intercept_, 'red')
    plt.grid()
    plt.tight_layout()
    plt.ylabel('DJI daily return')
    plt.xlabel(str(companies[i] + ' daily return'))
    plt.title(titles[i])
    print('The R^2 error for ' + companies[i] + ' vs DJI is ' + str(round(clf.score(X,y),5)))
    i = i + 1
plt.show()
# Out:
# The R^2 error for AAPL vs DJI is 0.51887
# The R^2 error for IBM vs DJI is 0.41859
# The R^2 error for JPM vs DJI is 0.55649

# %% [markdown]
# ### Huber daily returns regression of stocks against DJI
#
# In this exercise, the Huber regression is computed for the daily returns of Apple, IBM and JPM against those of the DJI. The Huber regression is similar to OLS except when analyzing outliers, whose loss function is the absolute error instead of the squared error. Outliers are defined as the data-points of the scaled to unity standard deviation distribution whose distance to the mean is larger than some parameter \(\epsilon\) (for this exercise \(\epsilon = 1.35\). This way the regression gives less importance to outliers without completely ignoring them. The figures below illustrate the result of the regression.  For each of the stocks the error is 0.51861, 0.36334 and 0.55458, respectively.

# %%
clf = HuberRegressor()

y = dji['Ret']
plt.figure(dpi=100, figsize=(12,4))
x_axis = np.linspace(-0.1,0.1,len(ibm['Ret'])).reshape(-1,1)
i = 0
companies = ['AAPL', 'IBM', 'JPM']
titles = ['Apple vs DJI Huber regression', 'IBM vs DJI Huber regression', 'JPM vs DJI Huber regression']
for X in [np.array(aapl['Ret']).reshape(-1,1), np.array(ibm['Ret']).reshape(-1,1), np.array(jpm['Ret']).reshape(-1,1)]:
    clf=clf.fit(X, y)
    plt.subplot(1,3,i+1)
    plt.scatter(X,y)
    plt.plot(x_axis, x_axis * clf.coef_ + clf.intercept_, 'red')
    plt.grid()
    plt.tight_layout()
    plt.ylabel('DJI daily return')
    plt.xlabel(str(companies[i] + ' daily return'))
    plt.title(titles[i])
    print('The R^2 error for ' + companies[i] + ' vs DJI is ' + str(round(clf.score(X,y),5)))
    i = i + 1
plt.show()
# Out:
# The R^2 error for AAPL vs DJI is 0.51861
# The R^2 error for IBM vs DJI is 0.36334
# The R^2 error for JPM vs DJI is 0.55458

# %% [markdown]
# ### Performance of the regression with outliers
#
# The results from the previous two exercises show that the R squared error is better (higher) for all of the regressed stocks when using OLS rather than Huber. This is due to the fact that there are not many real outliers in the dataset being studied. In order to study the error when more outliers are present, an outlier ratio is introduced by multiplying that proportion of the data by random integers in the range of 1 to 5.
#
# The R squared performance of the regressors is evaluated for different values of the outlier ratio. The results show that the Huber regression does not perform as well as the OLS regression for any outlier ratio. One explanation for this could be that the outliers present a symmetric distribution around the true value and the loss introduced by any of the outliers is compensated by its mirrored version. Moreover, the larger the outlier ratio, it is clear to see that the performance of the regression is worse.

# %%
np.random.seed(1234)
y = dji['Ret']
score_ols = np.zeros((3,50))
score_hub = np.zeros((3,50))
n = 0
for outlier_ratio in range(0,50):
    outlier_ratio = outlier_ratio / 100
    i = 0
    np.random.seed(1234)
    if outlier_ratio > 0:
        random_idxs = np.random.random_integers(1,len(ibm['Ret'])*outlier_ratio,int(len(ibm['Ret'])*outlier_ratio))
    outlier_mult = np.random.random_integers(1,5,int(len(ibm['Ret'])*outlier_ratio))
    ols = LinearRegression()
    hub = HuberRegressor()
    companies = ['AAPL', 'IBM', 'JPM']
    for X in [np.array(aapl['Ret']).reshape(-1,1), np.array(ibm['Ret']).reshape(-1,1), np.array(jpm['Ret']).reshape(-1,1)]:
        if outlier_ratio > 0:
            for k in range(len(random_idxs)):
                X[random_idxs[k]] = X[random_idxs[k]]*outlier_mult[k]
        ols = ols.fit(X, y)
        hub = hub.fit(X,y)
        score_ols[i,n] = round(ols.score(X,y),5)
        score_hub[i,n] = round(hub.score(X,y),5)
        i = i + 1
    n = n + 1

plt.figure(dpi=100, figsize=(5,3))
handlers = [None]*6
for n in range(0,3):
    handlers[2*n], = plt.plot(np.array(range(50))/100,score_ols[n],label=str(companies[n]+' OLS'))
    handlers[2*n+1], = plt.plot(np.array(range(50))/100,score_hub[n],label=str(companies[n] + ' Huber'))
plt.grid()
plt.title('R squared error for OLS and Huber regression')
plt.xlabel('Outlier ratio')
plt.ylabel('R squared error')
plt.legend(handles=handlers)
plt.show()

# %% [markdown]
# ## Robust Trading Strategies
#
# ### Moving average crossover
#
# In this exercise, the Moving Average Crossover strategy is studied. This strategy consists on buying stocks when the 20 day moving average is larger than the 50 moving average and conversely. The figures below show the crossover regions of both moving averages. When the area displayed is green, stocks are bought, and when it is red, stocks are sold. From observing these graphs, for this time period the strategy is succesful and provides positive returns.
#
# It is of interest to study the behaviour of the strategy when the previously used outliers are introduced (4 dates, 1.2 times the maximum of the series). Although the crossover points change slightly and the model is more volatile, the strategy is still successful.

# %%
i = 0
companies = ['AAPL', 'IBM', 'JPM']
plt.figure(dpi=100, figsize=(12,8))
handles = [None]*24
for x in [aapl, ibm, jpm, aapl2, ibm2, jpm2]:
    x_20 = x['Adj Close'].rolling(20).mean()
    x_50 = x['Adj Close'].rolling(50).mean()
    idx = np.argwhere(np.diff(np.sign(np.array(x_20) - np.array(x_50)))).flatten()
    idx = idx[np.where(idx > 50)]
    idx_buy = np.array(np.where(np.diff(np.sign(np.array(x_20) - np.array(x_50))) > 0)).flatten()
    idx_sell = np.array(np.where(np.diff(np.sign(np.array(x_20) - np.array(x_50))) < 0)).flatten()
    plt.subplot(2,3,i+1)
    handles[4*i], = plt.plot(x_20, label='20 day window',linewidth=2)
    handles[4*i+1], = plt.plot(x_50, label='50 day window',linewidth=2)
    handles[4*i+2], = plt.plot(x_20[idx_buy],'.', label='buy',markersize=15)
    handles[4*i+3], = plt.plot(x_20[idx_sell],'.', label='sell', markersize=15)
    plt.fill_between(x_20.index, x_20, x_50, where=x_20 >= x_50, facecolor='green',edgecolor='green', interpolate=True,alpha=0.6,hatch='//')
    plt.fill_between(x_20.index, x_20, x_50,where=x_20 <= x_50, facecolor='red',edgecolor='red',interpolate=True, alpha=0.6,hatch='//')
    if i > 2:
        plt.title(str('Moving average of ' + companies[i%3]) + ' with outliers')
    else:
        plt.title(str('Moving average of ' + companies[i%3]))
    plt.xlabel('date')
    plt.ylabel('price ($)')
    plt.grid()
    plt.tight_layout()
    plt.xticks(rotation=45)
    plt.legend(handles=handles[2*i:2*i+4])
    i = i + 1
plt.show()

# %% [markdown]
# ### Moving median crossover
#
# As it was explained in the previous section. Median estimators are more robust when using a normal distributed time series and, as such, they are less susceptible to outliers. In this exercise, the same steps are repeated as in part 1. However, here he median is used with the same window size of 20 and 50 days.
#
# A clear difference between the figures using both estimators is seen in the with of the crossover region of the two functions. They are not as far apart from each other and they lead to more crossover points. This estimator can, therefore, be useful for investors whose trading strategy is short term. Outliers increase the number of crossover points even more, especially for the JPM stock. Median crossover strategy is also successful for these stocks during this time period.

# %%
aapl_r = pd.DataFrame([189.09,192.03,212.79,164.54])
print(aapl_r.pct_change())
ibm_r = pd.DataFrame([141.54,141.66,135.69,])
ibm_r.pct_change()
# jpm_r = pd.DataFrame([1,2,3,4])
# jpm_r.pct_change()
# Out:
#           0
# 0       NaN
# 1  0.015548
# 2  0.108108
# 3 -0.226749

# %%
i = 0
companies = ['AAPL', 'IBM', 'JPM']
plt.figure(dpi=100, figsize=(12,8))
handles = [None]*24
for x in [aapl, ibm, jpm, aapl2, ibm2, jpm2]:
    x_20 = x['Adj Close'].rolling(20).median()
    x_50 = x['Adj Close'].rolling(50).median()
    idx = np.argwhere(np.diff(np.sign(np.array(x_20) - np.array(x_50)))).flatten()
    idx = idx[np.where(idx > 50)]
    idx_buy = np.array(np.where(np.diff(np.sign(np.array(x_20) - np.array(x_50))) > 0)).flatten()
    idx_sell = np.array(np.where(np.diff(np.sign(np.array(x_20) - np.array(x_50))) < 0)).flatten()
    plt.subplot(2,3,i+1)
    handles[4*i], = plt.plot(x_20, label='20 day window',linewidth=2)
    handles[4*i+1], = plt.plot(x_50, label='50 day window',linewidth=2)
    handles[4*i+2], = plt.plot(x_20[idx_buy],'.', label='buy',markersize=15)
    handles[4*i+3], = plt.plot(x_20[idx_sell],'.', label='sell', markersize=15)
    plt.fill_between(x_20.index, x_20, x_50, where=x_20 >= x_50, facecolor='green',edgecolor='green', interpolate=True,alpha=0.6,hatch='//')
    plt.fill_between(x_20.index, x_20, x_50,where=x_20 <= x_50, facecolor='red',edgecolor='red',interpolate=True, alpha=0.6,hatch='//')
    if i > 2:
        plt.title(str('Moving average of ' + companies[i%3]) + ' with outliers')
    else:
        plt.title(str('Moving average of ' + companies[i%3]))
    plt.xlabel('date')
    plt.ylabel('price ($)')
    plt.grid()
    plt.tight_layout()
    plt.xticks(rotation=45)
    plt.legend(handles=handles[2*i:2*i+4])
    i = i + 1
plt.show()

# %% [markdown]
# # Graphs in Finance
#
# Securities in the financial markets are not independent assets. They are affected by fluctuations of other stocks in the same sector, the overall market performance and other political and economic factors. In this section the topology of stocks in the SNP 500 and the use of graphs in finance will be studied.
#
# ## Selection of stocks
#
# First, a criterion must be chosen to select the stocks in the market, this can be based on the sector, the industry, location, stock price, etc. For this exercise, eight stocks belonging to the Oil & Gas Exploration & Production industry will be used. Moreover, the selected stocks are all from the state of Texas, which adds another layer of dependency among the securities. As it will be shown, this industry is highly correlated as it highly depends on the price of oil. It is also heavily influenced by politics, especially in the middle east, where it is used as diplomatic weapon. For this section log returns will be used. The figures below display the prices and log returns of the assets. Since the prices tend to fluctuate in the same way, it is to be expected that there will be a strong network.

# %%
stocks = pd.read_csv('snp_allstocks_2015_2019.csv')
dates = stocks['Date']
date_axis = [dt.datetime.strptime(d,'%Y-%m-%d').date() for d in dates]
info = pd.read_csv('snp_info.csv')
sector = info['GICS Sub Industry']
tickers = ['APA', 'COG', 'CXO', 'COP', 'FANG', 'EOG', 'MRO', 'NBL']
stocks = stocks[tickers]
stocks_norm = (stocks - stocks.mean()) / (stocks.max() - stocks.min())
stocks_r = np.log(stocks[tickers]) - np.log(stocks[tickers].shift(1))
plt.figure(dpi=100, figsize=(10,4))
plt.subplot(121)
plt.title('Oil and Gas SNP 500 stock prices')
plt.xlabel('date')
plt.ylabel('price ($)')
plt.plot(date_axis,stocks)
plt.xticks(rotation=45)
plt.legend(tickers)
plt.grid()
plt.tight_layout()
plt.subplot(122)
plt.title('Oil and Gas SNP 500 log returns')
plt.xlabel('date')
plt.ylabel('return')
plt.plot(date_axis,stocks_r)
plt.xticks(rotation=45)
plt.legend(tickers)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot a correlation matrix network
#
# The correlation matrix is used to infer the relationships between different stocks in a particular matrix. However, in order to visualize them, it is easier to use a network graph such as the one seen below for the stock log returns.
#
# Each of the nodes is a security and it is connected to other stocks through edges. These edges appear between stocks whose correlation is higher than a given threshold (in this case 0.7). For the rest of the section, the threshold will be chosen so that the only visible connections are those whose correlation coefficient is above the median. The dependencies between stocks are then clearly visible through the clustering of nodes and their connections. It can be seen that the topology of the network agrees with the values of the correlation matrix seen below. Since the major connections are all positive, there is no need to draw different edges for negatively correlated stocks. COP is the asset with the most edges in the network and FANG the least. COG is not displayed in the network at all because the highest correlation value it has is 0.49 with EOG and it is below the threshold value.

# %%
corr = stocks_r.corr() 
def plot_network(df, threshold = 0.7, reverse_threshold = False):
    links = df.stack().reset_index()
    links.columns = ['var1', 'var2','value']
    if reverse_threshold:
        links_filtered=links.loc[ (abs(links['value']) < threshold) & (links['var1'] != links['var2'])]
    else:
        links_filtered=links.loc[ (abs(links['value']) > threshold) & (links['var1'] != links['var2'])]
    G=nx.from_pandas_edgelist(links_filtered, 'var1', 'var2')
    nx.draw(G, with_labels=True, node_color='lightblue', node_size=2000, edge_color='black', linewidths=1, font_size=15)
plot_network(corr)
corr
# Out:
#            APA       COG       CXO       COP      FANG       EOG       MRO  \
# APA   1.000000  0.481213  0.694407  0.709889  0.625403  0.744480  0.729692
# COG   0.481213  1.000000  0.450708  0.439725  0.447197  0.492177  0.468102
# CXO   0.694407  0.450708  1.000000  0.700274  0.768564  0.799991  0.687043
# COP   0.709889  0.439725  0.700274  1.000000  0.654767  0.777119  0.800299
# FANG  0.625403  0.447197  0.768564  0.654767  1.000000  0.745617  0.627606
# EOG   0.744480  0.492177  0.799991  0.777119  0.745617  1.000000  0.743742
# MRO   0.729692  0.468102  0.687043  0.800299  0.627606  0.743742  1.000000
# NBL   0.709624  0.451680  0.705450  0.711720  0.635538  0.749014  0.720160
#
#            NBL
# APA   0.709624
# COG   0.451680
# CXO   0.705450
# COP   0.711720
# FANG  0.635538
# EOG   0.749014
# MRO   0.720160
# NBL   1.000000

# %% [markdown]
# ## Topology of the graph
#
# These strong relationships seen in the previous exercise were expected due to the high dependence of this industry on the oil price, and the political and economic context. Whenever the oil prices fluctuate, they have a heavy impact on the stock value of the companies that extract it.
#
# The correlation between two stocks is non-directed. This means that it has a reciprocal behavior i.e the correlation of A from B is the same as the correlation of B from A. For this reason it is incorrect to establish a direction in the edges of the graph. Other cases where this is necessary would be the propagation of news through the internet or the spread of a disease among the population. They have both an origin and a recipient and, therefore, any representative graph of such networks would be directed.
#
# Altering the order of the time series could have an effect on the correlation matrix and, therefore, the resulting network. If the relative order among all the stocks was to be kept the same, then the correlation matrix would remain untouched. This is because correlation is computed with sample pairs at each time period independently of what happened in the previous time steps. However, if the time series of two stocks were reorganized in any other way, the correlation matrix would change. For example, if two stocks were reorganized such that whenever one of the stocks had a positive return the other one would have a negative return, this would lead to a very negative correlation coefficient. This can be proved by the shuffled time series correlation matrix below. Although the order of the time series has changed, the relative positions of the returns from each stock at the same time step are the same. Because of this, the resulting correlation matrix is equal to the one of the non-shuffled time series.

# %%
shuffled_r = stocks_r.sample(frac=1, random_state=1).reset_index(drop=True)
shuffled_r.corr()
# Out:
#            APA       COG       CXO       COP      FANG       EOG       MRO  \
# APA   1.000000  0.481213  0.694407  0.709889  0.625403  0.744480  0.729692
# COG   0.481213  1.000000  0.450708  0.439725  0.447197  0.492177  0.468102
# CXO   0.694407  0.450708  1.000000  0.700274  0.768564  0.799991  0.687043
# COP   0.709889  0.439725  0.700274  1.000000  0.654767  0.777119  0.800299
# FANG  0.625403  0.447197  0.768564  0.654767  1.000000  0.745617  0.627606
# EOG   0.744480  0.492177  0.799991  0.777119  0.745617  1.000000  0.743742
# MRO   0.729692  0.468102  0.687043  0.800299  0.627606  0.743742  1.000000
# NBL   0.709624  0.451680  0.705450  0.711720  0.635538  0.749014  0.720160
#
#            NBL
# APA   0.709624
# COG   0.451680
# CXO   0.705450
# COP   0.711720
# FANG  0.635538
# EOG   0.749014
# MRO   0.720160
# NBL   1.000000

# %% [markdown]
# ## Spectral distance
#
# Thie previous exercises have focused on the correlation of the assets in order to construct a relationship graph. Now, a difference metric will be assessed to establish relationships between stocks. For this exercise the metric used will be the spectral distance. This is the euclidean distance of the Fourier transform of the stocks valuation time series. The spectral distance matrix and the resulting network for a threshold of 12 is seen below. Here the threshold is reversed, only the distances that are lower than 12 are displayed as edges.
#
# The network shows that EOG lies close to FANG, CXO, COP and DLB in the spectral euclidean space. This means that their frequency components are more similar than to the rest of the stocks. On the other hand, APA, COG and MRO do not lie close to any other security and, therefore, they are not displayed in the network.
#
# Spectral distances could be meaningful when analyzing how stocks fluctuate with respect to others. Low frequency components of the Fourier transform correspond to the slow changing prices and the high frequency components appear with rapid changes in the stock valuation. If the distance between the spectral components of two stocks is similar, it means that their valuation fluctuates in a similar way. Since the spectral distance being measured corresponds to the whole frequency spectrum, it cannot be determined whether two stocks are related by high or low frequency components. For this purpose, several spectral distances would have to be computed with different windowing functions.
#
# Just as with the correlation metric, the spectral distance is non-directed i.e its a reciprocal metric that has no origin or recipient. However, contrary to the correlation metric, if the time series were shuffled, just as in the previous exercise, the resulting Fourier coefficients would be different and the network structure would change. This is because the Fourier transform does depend on the previous time steps in order to be computed.

# %%
r_fft = np.zeros((len(tickers), len(stocks['APA'])-1))
plt.figure(dpi=100, figsize=(5,3))
plt.title('Fourier transform of the log returns')
plt.ylabel('magnitude')
plt.xlabel('Scaled frequency component')
plt.grid()
for i in range(len(tickers)):
    r_fft[i] = np.fft.fft(stocks_r.dropna().values[:,i])
    plt.plot(np.arange(-np.pi,np.pi,2*np.pi/len(r_fft[i])),r_fft[i])
plt.legend(tickers)
plt.show()

spect_dist = np.zeros((len(tickers), len(tickers)))
for i in range(len(tickers)):
    for n in range(len(tickers)):
        spect_dist[i,n] = np.linalg.norm(r_fft[i] - r_fft[n])
        
spect_dist_df = pd.DataFrame(spect_dist)
spect_dist_df.index, spect_dist_df.columns = tickers, tickers
plot_network(spect_dist_df, threshold=12, reverse_threshold=True)
spect_dist_df
# Out:
#             APA        COG        CXO        COP       FANG        EOG  \
# APA    0.000000  17.312260  13.452703  12.857371  15.876653  12.110445
# COG   17.312260   0.000000  16.181382  15.437947  16.448656  14.462222
# CXO   13.452703  16.181382   0.000000  11.772945  11.308365   9.697156
# COP   12.857371  15.437947  11.772945   0.000000  13.038706   9.042126
# FANG  15.876653  16.448656  11.308365  13.038706   0.000000  11.358769
# EOG   12.110445  14.462222   9.697156   9.042126  11.358769   0.000000
# MRO   15.028981  20.259342  16.212009  13.670005  18.061778  14.950759
# NBL   13.327945  16.578639  13.040785  12.254334  14.785146  11.164446
#
#             MRO        NBL
# APA   15.028981  13.327945
# COG   20.259342  16.578639
# CXO   16.212009  13.040785
# COP   13.670005  12.254334
# FANG  18.061778  14.785146
# EOG   14.950759  11.164446
# MRO    0.000000  15.861570
# NBL   15.861570   0.000000

# %% [markdown]
# ## Correlation network for raw prices
#
# For the whole section, the log returns time series were used. It is of interest to evaluate what the previous results would be if the stock prices were used.
#
# The code below displays the correlation matrix of the prices and the resulting network for a threshold of 0.8. Here, the correlation coefficients are higher than that of the log returns. Correlation matrices of stock prices tend to be positively biased because markets tend to have a positive trend. This can give a wrong misconception of what the real relationship between the stocks is. The network is composed of two clusters, the first one contains the stocks APA and NBL, and the second one, CXO, EOG and FANG. Again, very few correlation coefficients are negative.

# %%
corr = stocks.corr() 
plot_network(corr, threshold=0.8)
corr
# Out:
#            APA       COG       CXO       COP      FANG       EOG       MRO  \
# APA   1.000000  0.374200 -0.016277 -0.013208 -0.287149 -0.075045  0.485643
# COG   0.374200  1.000000  0.173318  0.367216 -0.043876  0.151920  0.640085
# CXO  -0.016277  0.173318  1.000000  0.410453  0.906199  0.863937  0.170033
# COP  -0.013208  0.367216  0.410453  1.000000  0.434139  0.714878  0.786379
# FANG -0.287149 -0.043876  0.906199  0.434139  1.000000  0.893890  0.011129
# EOG  -0.075045  0.151920  0.863937  0.714878  0.893890  1.000000  0.382994
# MRO   0.485643  0.640085  0.170033  0.786379  0.011129  0.382994  1.000000
# NBL   0.836986  0.448317 -0.099020  0.261587 -0.328492 -0.046782  0.737480
#
#            NBL
# APA   0.836986
# COG   0.448317
# CXO  -0.099020
# COP   0.261587
# FANG -0.328492
# EOG  -0.046782
# MRO   0.737480
# NBL   1.000000

# %% [markdown]
# For the same reasons as for the log prices, the network is non-directed, and as such the network does not have directed edges. Moreover, a shuffle of the prices, while keeping the relative time steps between stocks, would not affect the resulting correlation matrix, in contrast, any other type of shuffle, would.
#
# A disadvantage of using raw prices over log returns for long time periods is that volatility is higher as inflation grows. This gives more weight to samples latter in time than those at the beginning. Moreover, prices are not independent, returns at the beginning of the time series have an effect on the prices at later time steps. This gives more weight to the samples at the beginning of the time period than at the end.
